# %% [markdown]
# # Capstone - Initial EDA
#
# Some EDA will be completed, using the previously cleaned London Airbnb dataset.

# %%
# imports

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import cleaned dataset:
airbnb_ldn = pd.read_csv('airbnb_ldn_final.csv')

# %%
airbnb_ldn.shape
# Out:
# (32686, 39)

# %%
# drop 'Unnamed', column added due to additional index column being added with the import of the cleaned data:
airbnb_ldn.drop(columns = 'Unnamed: 0', inplace=True)

# %%
airbnb_ldn.columns
# Out:
# Index(['Listing Title', 'Property Type', 'Listing Type', 'City', 'Zipcode',
#        'Number of Reviews', 'Bedrooms', 'Bathrooms', 'Max Guests',
#        'Airbnb Superhost', 'Cancellation Policy', 'Cleaning Fee (Native)',
#        'Extra People Fee(Native)', 'Check-in Time', 'Checkout Time',
#        'Minimum Stay', 'Latitude', 'Longitude', 'Overall Rating',
#        'Airbnb Communication Rating', 'Airbnb Accuracy Rating',
#        'Airbnb Cleanliness Rating', 'Airbnb Checkin Rating',
#        'Airbnb Location Rating', 'Airbnb Value Rating', 'Amenities',
#        'Airbnb Host ID', 'Host Listing Count', 'guest_controls',
#        'Pets Allowed', 'Count Available Days LTM', 'Count Blocked Days LTM',
#        'Count Reservation Days LTM', 'Occupancy Rate LTM',
#        'Number of Bookings LTM',
#        'Number of Bookings LTM - Number of observed month',
#        'Average Daily Rate (Native)', 'Annual Revenue LTM (Native)'],
#       dtype='object')

# %% [markdown]
# The columns will be split between numerical, categorical and target variables:

# %%
# split the dataframe into numerical columns, categorical columns and the target column:
X_num_cols = (airbnb_ldn.select_dtypes(include=['int', 'float64'])).drop(columns='Annual Revenue LTM (Native)')
X_cat_cols = airbnb_ldn.select_dtypes(include='object')
y = airbnb_ldn['Annual Revenue LTM (Native)']

# %% [markdown]
# Now the columns have been split into their relevant subsets, the appropriate EDA techniques can be applied.
#
# Starting with looking at the numerical columns. Histograms for each column will be created, to gain an idea of the range of values, distributions and general trends.

# %%
# create a subplots structure with 3 columns and 8 rows
cols = 3
rows = len(X_num_cols.columns)//cols + 1

plt.figure(figsize=(17, 20))
plt.tight_layout()
plt.subplots_adjust(hspace = 1)
plt.suptitle('Numerical Columns Variable Distributions', y=0.92)

for i, column in enumerate(X_num_cols.columns):
    ax = plt.subplot(rows, cols, i+1)
    ax.set_title(f"Feature: {column}", size=10)
    ax.hist(X_num_cols[column], bins=100)


plt.show()

# %% [markdown]
# There is a substantial variation in the scale and distribution of the different numerical columns. The different numerical columns can be somewhat grouped, as different columns share similar characteristics:
#
# Group 1 - Property Features:
# - Bathrooms
# - Max Guests (there is no 'number of bedrooms' column, hence the Max guests will be the column to indicate property size)
#
# Group 2 - Location:
# - Longitude
# - Latitude
#
# Group 3 - Booking Related:
# - Cleaning Fee (Native)
# - Extra people fee (Native)
# - Minimum Stay
# - Count Available Days LTM
# - Count Blocked Days LTM
# - Count Reservation Days LTM
# - Occupancy Rate LTM
# - Number of Bookings LTM
# - Number of Bookings LTM - Number of observed month
# - Average Daily Rate (Native)
#
#
# Group 4 - Reviews:
# - Number of Reviews
# - Airbnb Communication Rating
# - Airbnb Accuracy Rating
# - Airbnb Cleanliness Rating
# - Airbnb Checkin Rating
# - Airbnb Location Rating
# - Airbnb Value Rating
# - Overall Rating
#
# Group 5 - Host Related:
# - Airbnb Host ID
# - Host Listing Count

# %%
X_num_cols.columns
# Out:
# Index(['Number of Reviews', 'Bathrooms', 'Max Guests', 'Cleaning Fee (Native)',
#        'Extra People Fee(Native)', 'Minimum Stay', 'Latitude', 'Longitude',
#        'Overall Rating', 'Airbnb Communication Rating',
#        'Airbnb Accuracy Rating', 'Airbnb Cleanliness Rating',
#        'Airbnb Checkin Rating', 'Airbnb Location Rating',
#        'Airbnb Value Rating', 'Airbnb Host ID', 'Host Listing Count',
#        'Count Available Days LTM', 'Count Blocked Days LTM',
#        'Count Reservation Days LTM', 'Occupancy Rate LTM',
#        'Number of Bookings LTM',
#        'Number of Bookings LTM - Number of observed month',
#        'Average Daily Rate (Native)'],
#       dtype='object')

# %% [markdown]
# ## Column Correlations
#
# During the cleaning stage, several columns that were deemed redundant were dropped. Columns meaning must be explored further, correlations between the various numerical columns will be found, to determine if any columns are semantically the same. All individual variable columns must be independent of each other (have low correlations), otherwise future models can be negatively effected.

# %%
# calculate all the correlations between each independent numerical variable

def plot_corr_heatmap(X_num_cols):
    corr_df = X_num_cols.corr()

    # mask for upper-triangle
    mask = np.triu(corr_df)

    # vaisualise heatmap
    plt.figure(figsize=(20, 20))
    sns.heatmap(corr_df.round(2),
                annot=True,
                center=0,
                vmax=1,
                vmin=-1,
                mask=mask,
                cmap='coolwarm')
    plt.show()

plot_corr_heatmap(X_num_cols)

# %% [markdown]
# The above correlation headmap shows there are some significant correlations several of the independent variables. These will be worked through on a case-by-case basis.
#
# To begin, the 'Number of Bookings LTM and 'Number of Bookings LTM - Number of observed Month' will be addressed:

# %%
# Histograms of both will be produced:
plt.subplots(1,2, figsize=(20,10))

plt.subplot(1,2,1)
plt.hist(airbnb_ldn['Number of Bookings LTM'], bins=500)
plt.title('Number of Bookings LTM- Histogram')
plt.xlabel('Number of Bookings LTM')
plt.ylabel('Frequency of Occurances')

plt.subplot(1,2,2)
plt.hist(airbnb_ldn['Number of Bookings LTM - Number of observed month'], bins=500)
plt.title('Number of Bookings LTM - Number of observed month')
plt.xlabel('Number of Bookings LTM - Number of observed month')
plt.ylabel('Frequency of Occurances')


plt.show()

# %% [markdown]
# Both columns follow similar 'right-skewed' distributions, with the maximum value for both being above 200. 'Number of Bookings LTM - Number of observed month' (LTM-OM) has negative values, whereas all of the 'Number of Bookings LTM' (LTM) are positive. LTM has a a greater quantity of values with a zero (or very close to) value, this could suggest that all negative valeus in the (LTM-OM) column, are considered '0' values in the LTM column. The meaning of the LTM-OM column is not immediatly obvious, it will be explored further:

# %%
print(f"The maximum value for LTM-OM is {airbnb_ldn['Number of Bookings LTM - Number of observed month'].max()}, and the min value is {airbnb_ldn['Number of Bookings LTM - Number of observed month'].min()}.")
print(f"The maximum value for LTM is: {airbnb_ldn['Number of Bookings LTM'].max()}, and the min value is {airbnb_ldn['Number of Bookings LTM'].min()}.")
# Out:
# The maximum value for LTM-OM is 238, and the min value is -11.
# The maximum value for LTM is: 239, and the min value is 0.

# %% [markdown]
# Both LTM-OM and LTM have very similar max values and distributions. To address the correlation issue for these two columns, it would be best to drop one. They both share very similar max values and distributions, but the meaning of LTM-OM is not entirely clear and the existence of the negative values could present problems at later stages of the modelling. Therefore, LTM-OM will be dropped.

# %%
# drop the column from both relevant dataframes within this worksheet:
X_num_cols.drop(columns='Number of Bookings LTM - Number of observed month', inplace=True)
airbnb_ldn.drop(columns='Number of Bookings LTM - Number of observed month', inplace=True)

# %% [markdown]
# The three columns, 'Count Available Days LTM' (CAD), 'Count Blocked Days LTM' (CBD) and 'Count Reservation Days LTM' (CRD), all have very high correlations; CBD and CRD have a perfect inverse correlation.
# CBD and CRD will be looked into first:

# %%
# Histograms of both will be produced:
plt.subplots(1,2, figsize=(20,10))

plt.subplot(1,2,1)
plt.hist(airbnb_ldn['Count Blocked Days LTM'], bins=500)
plt.title('Count Blocked Days LTM - Histogram')
plt.xlabel('Count Blocked Days LTM')
plt.ylabel('Frequency of Occurances')

plt.subplot(1,2,2)
plt.hist(airbnb_ldn['Count Available Days LTM'], bins=500)
plt.title('Count Available Days LTM - Histogram')
plt.xlabel('Count Available Days LTM')
plt.ylabel('Frequency of Occurances')


plt.show()

# %% [markdown]
# As expected, both columns histograms are mirrored versions of each other and keeping them both in the dataframe is pointless; one will be dropped. For the purpose of modelling, it is slightly 'computationally cheap' to work with more smaller numbers rather than more larger ones. For that reason, 'Count Blocked Days LTM' will be dropped, as it have a higher quantity of larger numbers.

# %%
# drop the column from both relevant dataframes within this worksheet:
X_num_cols.drop(columns='Count Blocked Days LTM', inplace=True)
airbnb_ldn.drop(columns='Count Blocked Days LTM', inplace=True)

# %% [markdown]
# Now the 'Count Reservation Days LTM and 'Count Available Days LTM' can be compared:

# %%
# Histograms of both will be produced:
plt.subplots(1,2, figsize=(20,10))

plt.subplot(1,2,1)
plt.hist(airbnb_ldn['Count Reservation Days LTM'], bins=500)
plt.title('Count Reservation Days LTM - Histogram')
plt.xlabel('Count Reservation Days LTM')
plt.ylabel('Frequency of Occurances')

plt.subplot(1,2,2)
plt.hist(airbnb_ldn['Count Available Days LTM'], bins=500)
plt.title('Count Available Days LTM - Histogram')
plt.xlabel('Count Available Days LTM')
plt.ylabel('Frequency of Occurances')

plt.show()

# %% [markdown]
# Both histograms follow fairly similar trends, although CRD follows more of a consistent 'right-skewed' distribution. Both graphs will be 'log' transformed, to see how this changes the distribution:

# %%
# add 1 to both columns to avoid taking the log of 0
c_d_log = np.log(X_num_cols[['Count Reservation Days LTM', 'Count Available Days LTM']] + 1 )

# %%
# create a subplots structure with 4 columns and 5 rows
cols = 4
rows = len(c_d_log.columns)//cols + 1

plt.figure(figsize=(25, 15))
plt.tight_layout()
plt.subplots_adjust(hspace = 1)
plt.suptitle('Log-Transformed Variable Distributions', y=0.92)

for i, column in enumerate(c_d_log.columns):
    ax = plt.subplot(rows, cols, i+1)
    ax.set_title(f"Feature: {column}", size=10)
    ax.hist(c_d_log[column], bins=100, color='darkgreen')

plt.show()

# %% [markdown]
# The two columns will be plotted against each other:

# %%
plt.figure()
plt.scatter(airbnb_ldn['Count Reservation Days LTM'], airbnb_ldn['Count Available Days LTM'])
plt.xlabel('Count Reservation Days LTM')
plt.ylabel('Count Available Days LTM')
plt.title('Available Days Against Reservation Days')
plt.show()

# %% [markdown]
# **Come back to look at the log graphs in greater detail**

# %% [markdown]
# The various numerical columns will be plotted against the target column, to determine relative correlations:

# %%
X_num_cols.head().T
# Out:
#                                     0          1         2         3         4
# Number of Reviews                   9         11         1        20         0
# Bathrooms                           2          1         2         1         1
# Max Guests                          6          4         3         4         2
# Cleaning Fee (Native)           154.8        0.0       0.0      34.8       0.0
# Extra People Fee(Native)          0.0        0.0       0.0       2.5       0.0
# Minimum Stay                        3          1         7         5         5
# Latitude                     51.43105   51.43399    51.435  51.43531  51.43532
# Longitude                    -0.26074   -0.25656    -0.257  -0.25648  -0.25413
# Overall Rating                    4.1        4.8       5.0       4.8       4.0
# Airbnb Communication Rating       9.0       10.0      10.0      10.0      10.0
# Airbnb Accuracy Rating            8.0        9.0       8.0      10.0      10.0
# Airbnb Cleanliness Rating         8.0       10.0      10.0       9.0       6.0
# Airbnb Checkin Rating             9.0       10.0      10.0      10.0      10.0
# Airbnb Location Rating            8.0        9.0       8.0       9.0       9.0
# Airbnb Value Rating               8.0       10.0      10.0       9.0       9.0
# Airbnb Host ID               91050428  476914024  20985539  65911292   4350839
# Host Listing Count                4.0        NaN       NaN       4.0       0.0
# Pets Allowed                    False      False     False     False     False
# Count Available Days LTM           10        163        74       138         0
# Count Reservation Days LTM          5         91         1       108         0
# Occupancy Rate LTM                 40         67         2        94        55
# Number of Bookings LTM              1         26         0        13         0
# Average Daily Rate (Native)     244.1      153.3     233.1      94.8      44.2

# %%
plt.subplots(1,2, figsize=(20,20))

plt.subplot(1,2,1)
plt.scatter(X_num_cols['Count Available Days LTM'], y)
plt.xlabel('Count Available Days LTM')
plt.ylabel('Annual Revenue LTM')
plt.title('Annual Revenue against Available Days (Both LTM)')

plt.subplot(1,2,2)
plt.scatter(X_num_cols['Count Reservation Days LTM'], y)
plt.xlabel('Count Reservation Days LTM')
plt.ylabel('Annual Revenue LTM')
plt.title('Annual Revenue against Reserved Days (Both LTM)')

plt.show()

# %%
print(f"The correlation between the annual revenue and the number of available days is {round(y.corr(X_num_cols['Count Available Days LTM']),2)}.")
print(f"The correlation between the annual revenue and the number of reservation days is {round(y.corr(X_num_cols['Count Reservation Days LTM']),2)}.")
# Out:
# The correlation between the annual revenue and the number of available days is 0.56.
# The correlation between the annual revenue and the number of reservation days is 0.57.

# %% [markdown]
# The 'Count Reservation Days LTM' column's 'log' distribution, follows more of a normally distributed trend than the 'Count Available Days LTM' 'log' graph does. Also, the 'Count Reservation Days LTM' column has a slightly stronger correlation with the target column (0.57 against 0.56). For these reasons, the 'Count Available Days LTM' column will be dropped.

# %%
X_num_cols.drop(columns='Count Available Days LTM', inplace=True)
airbnb_ldn.drop(columns='Count Available Days LTM', inplace=True)

# %% [markdown]
# Looking at other variable columns that have high correlations. Particularly, looking amoungst the various 'Rating' columns. There are several categories for the different ratings with 'Overall Rating' being the ultimate main rating.
#
# The 'Overall Rating' column will be the most important for the future models. The other sub-rating columns will be assessed.
#
# The two sub-rating columns most strongly correlated with the 'Overall Rating' column are the 'Accuracy Rating' and 'Value Rating. The 'Accuracy Rating' column is not particularly valuable when attempting to determine the 'Overall Revenue', it can therefore be dropped.
#
# The 'Value Rating' column needs a bit more consideration. 'Value Rating' when considering the success of a property in terms of the 'Annual Revenue' is very important. A customer may stay in an airbnb property, pay the original fee, yet feel the property is overvalued and hence deter the customer from re-visiting the property/recommending it, potentially causing future income loss. The fact the 'Value Rating' column is so strongly correlated with the 'Overall Rating' (0.85), suggests that the described scenario is unusual. As the strong correlation between the two variables, confirms that on the whole, a property that has a high 'Overall Rating' will also have a high 'Value Rating'. To effectively produce future models, this level of linearity between variables is unacceptable, so for now, the least important of the two 'Airbnb Value Rating' will be dropped; it may still be included to some degree in subsequent modelling.

# %%
# drop mentioned columns from both dataframes
X_num_cols.drop(columns=['Airbnb Value Rating', 'Airbnb Accuracy Rating'], inplace=True)
airbnb_ldn.drop(columns=['Airbnb Value Rating', 'Airbnb Accuracy Rating'], inplace=True)

# %% [markdown]
# The remaining rating columns are 'Communciation', 'Checkin', 'Location' and 'Cleaniless'. These four columns all have some correlation with the 'Overall Rating',, but 'Location' is the least correlated. Location is also a column that could be particularly useful in the modelling stage. It makes sense that location and overall rating are the least correlated, location can be the critical factor in someones decision for where to rent (it would not be uncommon for someone to rent a property purley on it's location, regardless of how nice/well equiped hte property is).
#
# The other three columns 'Communication', 'Checkin' and 'Cleaniless' are all more strongly correlated with the target column and not massively relevant for the purposes of the final model; these columns can  be dropped.

# %%
# drop rating columns for 'communication', 'checkin' and 'cleanliness'
X_num_cols.drop(columns=['Airbnb Cleanliness Rating', 'Airbnb Checkin Rating', 'Airbnb Communication Rating'], inplace=True)
airbnb_ldn.drop(columns=['Airbnb Cleanliness Rating', 'Airbnb Checkin Rating', 'Airbnb Communication Rating'], inplace=True)

# %% [markdown]
# Now the majority of major situations of linearity between the variable columns has been addressed. An updated correlation heatmap will be produced to determine the resultant impact:

# %%
# calculate all the correlations between each independent numerical variable

def plot_corr_heatmap(X_num_cols):
    corr_df = X_num_cols.corr()

    # mask for upper-triangle
    mask = np.triu(corr_df)

    # vaisualise heatmap
    plt.figure(figsize=(20, 20))
    sns.heatmap(corr_df.round(2),
                annot=True,
                center=0,
                vmax=1,
                vmin=-1,
                mask=mask,
                cmap='coolwarm')
    plt.show()

plot_corr_heatmap(X_num_cols)

# %% [markdown]
# Some of the columns still exhibit levels of collinearity, such as 'Number of Bookings LTM' and 'Count Reservation Days LTM'. For now, no more columns will be dropped. A linear regression model with a P1 penalty will be used to determine variable coefficients and subsequent variable value within the model (to be completed in following workbook).

# %% [markdown]
# ## Categorical Columns

# %%
X_cat_cols.head().T
# Out:
#                                                                      0  \
# Listing Title                        Cozy 2BR house with a garden view
# Property Type                                              Entire home
# Listing Type                                               entire_home
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             2
# Airbnb Superhost                                                     f
# Cancellation Policy                        strict_14_with_grace_period
# Check-in Time                                      12:00 PM - 12:00 AM
# Checkout Time                                                 10:00 AM
# Amenities            ['Free parking on premises', 'Air conditioning...
# guest_controls       {"allows_children": true, "allows_infants": tr...
#
#                                                                      1  \
# Listing Title          GuestReady - Amazing home with a private garden
# Property Type                                              Entire home
# Listing Type                                               entire_home
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             2
# Airbnb Superhost                                                     t
# Cancellation Policy                                                NaN
# Check-in Time                                       3:00 PM - 12:00 AM
# Checkout Time                                                 11:00 AM
# Amenities            ['Wifi', 'Kitchen', 'Dryer', 'Dedicated worksp...
# guest_controls       {"allows_children": true, "allows_infants": tr...
#
#                                                                      2  \
# Listing Title                            Cosy cottage on Richmond Park
# Property Type                                              Entire home
# Listing Type                                               entire_home
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             1
# Airbnb Superhost                                                     f
# Cancellation Policy                                                NaN
# Check-in Time                                            After 3:00 PM
# Checkout Time                                                 11:00 AM
# Amenities            ['Free parking on premises', 'Air conditioning...
# guest_controls       {"allows_children": false, "allows_infants": f...
#
#                                                                      3  \
# Listing Title        Entire Flat. Free parking, Garden , Richmond park
# Property Type                                       Entire rental unit
# Listing Type                                               entire_home
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             2
# Airbnb Superhost                                                     f
# Cancellation Policy                        strict_14_with_grace_period
# Check-in Time                                       3:00 PM - 11:00 PM
# Checkout Time                                                 11:00 AM
# Amenities            ['Free parking on premises', 'Wifi', 'Kitchen'...
# guest_controls       {"allows_children": true, "allows_infants": tr...
#
#                                                                      4
# Listing Title         Maisonette inbetween Richmond Park and Wimbledon
# Property Type                              Private room in rental unit
# Listing Type                                              private_room
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             1
# Airbnb Superhost                                                     f
# Cancellation Policy                        strict_14_with_grace_period
# Check-in Time                                      12:00 PM - 10:00 PM
# Checkout Time                                                 11:00 AM
# Amenities            ['Free parking on premises', 'Wifi', 'Breakfas...
# guest_controls       {"allows_children": false, "allows_infants": f...

# %% [markdown]
# ## Postcode Relevance
#
# The first piece of EDA will be looking at the influence different regions have. To accurately model the dataset based on regions, the different rows must be grouped based on relevant locational differences. There are several columns that have locational information, these are: 'City', 'Zipcode' (sometimes referred to as Postcode), 'Latitude' and 'Longitude'. All of these different columns contain information that can and will be useful at different points in this project. For now, the easiest way to split the various rows of information is using the 'Zipcode' column.
#
# Dataframes will be created for each of the different main London postal code prefix regions (denoted by the first or first two characters of the Zipcode). These are: W, WC, SW, NW, N, E, EC, SE.

# %%
# Create dataframes for each of the different postcode combinations in London:
w_zip = airbnb_ldn[airbnb_ldn['Zipcode'].str.slice(0,1).str.contains('W') &
                    ~airbnb_ldn['Zipcode'].str.slice(1,2).str.contains('C')]

n_zip = airbnb_ldn[airbnb_ldn['Zipcode'].str.slice(0,1).str.contains('N') &
                    ~airbnb_ldn['Zipcode'].str.slice(1,2).str.contains('E') &
                    ~airbnb_ldn['Zipcode'].str.slice(1,2).str.contains('W')]

e_zip = airbnb_ldn[airbnb_ldn['Zipcode'].str.slice(0,1).str.contains('E') &
                    ~airbnb_ldn['Zipcode'].str.slice(1,2).str.contains('C')]

wc_zip = airbnb_ldn[airbnb_ldn['Zipcode'].str.contains('WC')]

nw_zip = airbnb_ldn[airbnb_ldn['Zipcode'].str.slice(0,2).str.contains('NW')]

sw_zip = airbnb_ldn[airbnb_ldn['Zipcode'].str.slice(0,2).str.contains('SW')]

se_zip = airbnb_ldn[airbnb_ldn['Zipcode'].str.slice(0,2).str.contains('SE')]

ec_zip = airbnb_ldn[airbnb_ldn['Zipcode'].str.slice(0,2).str.contains('EC')]

# %% [markdown]
# The main dataframe has been split into separate dataframes for each London postcode prefix.
#
# The mean of the 'Average Daily Rate (Native)', will be plotted:

# %%
plt.figure()
plt.bar('WC', wc_zip['Average Daily Rate (Native)'].mean())
plt.bar('W', w_zip['Average Daily Rate (Native)'].mean())
plt.bar('SW', sw_zip['Average Daily Rate (Native)'].mean())
plt.bar('EC', ec_zip['Average Daily Rate (Native)'].mean())
plt.bar('NW', nw_zip['Average Daily Rate (Native)'].mean())
plt.bar('N', n_zip['Average Daily Rate (Native)'].mean())
plt.bar('E', e_zip['Average Daily Rate (Native)'].mean())
plt.bar('SE', se_zip['Average Daily Rate (Native)'].mean())
plt.xlabel('Postcode')
plt.ylabel('Average Daily Rate, £')
plt.title('Average Daily Rental Rate for London Postcodes')
plt.show()

# %% [markdown]
# Looking at the bar chart above, it can be seen that the three most expensive regions all have a 'W' in their postcode prefix. This would indicate, that rental properties west of central in London, tend to demand a higher daily rental rate.
#
# Hence, an initial insight is that there does definitely seem to be some correlation between London region and average daily rental rate. Will the conclusion being that properties with a 'W' in their prefix tend to be more expensive to rent.
#
# Now, the quantity of Airbnb properties within different postcodes will be investigated:

# %%
# determining the number of airbnb properties within each postcode:

plt.figure()
plt.bar('WC', len(wc_zip))
plt.bar('W', len(w_zip))
plt.bar('SW', len(sw_zip))
plt.bar('EC', len(ec_zip))
plt.bar('NW', len(nw_zip))
plt.bar('N', len(n_zip))
plt.bar('E', len(e_zip))
plt.bar('SE', len(se_zip))
plt.xlabel('Postcode')
plt.ylabel('Property Count')
plt.title('Quantity of Properties in Different London Postcodes')
plt.show()

# %% [markdown]
# From the bar chart above, it can be seen that 'SW' and 'W' are the two postal regions with the highest quantity of Airbnb properties, these are also two of the most expensive areas to rent.
#
# Initially, it could be suggested that W and SW would be good places to invest in an Airbnb property. This will be investigated further to determine the relative success of Airbnb properties within these areas:

# %%
# plotting average overall rating against postcode region:

plt.figure()
plt.bar('WC', wc_zip['Overall Rating'].mean())
plt.bar('W', w_zip['Overall Rating'].mean())
plt.bar('SW', sw_zip['Overall Rating'].mean())
plt.bar('EC', ec_zip['Overall Rating'].mean())
plt.bar('NW', nw_zip['Overall Rating'].mean())
plt.bar('N', n_zip['Overall Rating'].mean())
plt.bar('E', e_zip['Overall Rating'].mean())
plt.bar('SE', se_zip['Overall Rating'].mean())
plt.xlabel('Postcode')
plt.ylabel('Average Overall Rating')
plt.title('Average Airbnb Property Rating for Different London Postcodes')
plt.show()

# %% [markdown]
# The results are very close, but it looks as though 'SW' potentially has the highest average rating. This will be confirmed numerically:

# %%
print(f"The average overall rating for WC properties is {wc_zip['Overall Rating'].mean()} stars")
print(f"The average overall rating for W properties is {w_zip['Overall Rating'].mean()} stars")
print(f"The average overall rating for SW properties is {sw_zip['Overall Rating'].mean()} stars")
print(f"The average overall rating for EC properties is {ec_zip['Overall Rating'].mean()} stars")
print(f"The average overall rating for NW properties is {nw_zip['Overall Rating'].mean()} stars")
print(f"The average overall rating for N properties is {n_zip['Overall Rating'].mean()} stars")
print(f"The average overall rating for E properties is {e_zip['Overall Rating'].mean()} stars")
print(f"The average overall rating for SE properties is {se_zip['Overall Rating'].mean()} stars")
# Out:
# The average overall rating for WC properties is 4.576090604026845 stars
# The average overall rating for W properties is 4.593088485975516 stars
# The average overall rating for SW properties is 4.662279273638072 stars
# The average overall rating for EC properties is 4.584096109839816 stars
# The average overall rating for NW properties is 4.591134413727359 stars
# The average overall rating for N properties is 4.666709886547812 stars
# The average overall rating for E properties is 4.641505791505791 stars
# The average overall rating for SE properties is 4.670670859538784 stars

# %% [markdown]
# It can be seen that SW, N and SE, are the leaders with approximately the same average rating of 4.67.
#
# Now the average occupancy rate for each postcode will be assessed. Areas that charge a lot, have lots of properties and high ratings may not have much demand and hence can't necessarily be considered successful. This plot will be very influencial throughout the entire analysis:

# %%
# plotting average occupancy rate against postcode region:

plt.figure()
plt.bar('WC', wc_zip['Occupancy Rate LTM'].mean())
plt.bar('W', w_zip['Occupancy Rate LTM'].mean())
plt.bar('SW', sw_zip['Occupancy Rate LTM'].mean())
plt.bar('EC', ec_zip['Occupancy Rate LTM'].mean())
plt.bar('NW', nw_zip['Occupancy Rate LTM'].mean())
plt.bar('N', n_zip['Occupancy Rate LTM'].mean())
plt.bar('E', e_zip['Occupancy Rate LTM'].mean())
plt.bar('SE', se_zip['Occupancy Rate LTM'].mean())
plt.xlabel('Postcode')
plt.ylabel('Average Occupancy Rate LTM')
plt.title('Average Airbnb Property Occupancy Rate (LTM) for Different London Postcodes')
plt.show()

# %% [markdown]
# The graph above shows that on the whole, all London postal regions have very high average occupation rates over the last 12 months; with EC having the highest. The previously identified areas of high rental income (WC, W, SW) all have average occupancy rates over 70%, proving that demand is high regardless of the rental amount.
#
# Hence, an immediate insight to prospective Airbnb property investors would be that purchasing a property with a W postcode would be a safebet in ensuring a high return on your initial investment. High rental rates, high overall ratings and high occupancy rates point to a very successful region.

# %% [markdown]
# **Looking at the correlation between overall rating and daily rental rate**
#
# This comparison will be completed to see how the 'Avaerage Daily Rate' and the overall rating the property receives are related.
#
# First, the number of variables of overall ratings will be determined:

# %%
print(airbnb_ldn['Overall Rating'].unique())
print(f"The maximum rating a property can receive is {airbnb_ldn['Overall Rating'].max()} stars")
print(f"The minimum rating a property can receive is {airbnb_ldn['Overall Rating'].min()} stars")
# Out:
# [4.1 4.8 5.  4.  4.7 4.2 4.9 4.4 3.5 4.5 4.6 2.4 3.4 4.3 3.9 3.  1.  3.8
#  3.6 3.2 3.1 2.  2.5 3.3 2.8 3.7 1.5 2.9 1.6 2.6 2.2 2.7 2.1]
# The maximum rating a property can receive is 5.0 stars
# The minimum rating a property can receive is 1.0 stars

# %%
plt.figure()
plt.hist(airbnb_ldn['Overall Rating'], bins = 50)
plt.ylabel('Quantity of rating occurances')
plt.xlabel('Rating')
plt.title('Histogram for Occurances of Different Property Ratings')
plt.show()

# %% [markdown]
# Can see that the vast majority of ratings are above approximately 4.2 stars. Hence, the majority of London airbnb rental properties can be deemed to be off a high quality already.
#
# These ratings and the Average daily rate will now be compared:

# %%
plt.figure()
plt.scatter(airbnb_ldn['Overall Rating'], airbnb_ldn['Average Daily Rate (Native)'])
plt.xlabel('Overall Rating, customer stars (1 to 5)')
plt.ylabel('Average Daily Rate, £')
plt.title('Average Property Daily rate against the Overall Customer Rating')
plt.show()

# %%
plt.figure()
(airbnb_ldn.groupby('Overall Rating')['Average Daily Rate (Native)'].mean()).plot(marker ='o', color ='pink')
plt.xlabel('Overall Rating, customer stars (1 to 5)')
plt.ylabel('Average Daily Rate, £')
plt.title('Average Property Daily rate against the Overall Customer Rating')
plt.show()

# %%
# ranged data

X_values = ['1*', '2-2.9*', '3-3.9*', '4-4.9*', '5*']

y_values = [
            airbnb_ldn[(airbnb_ldn['Overall Rating'] >= 1) & (airbnb_ldn['Overall Rating'] <= 1.9)]['Average Daily Rate (Native)'].mean(),
            airbnb_ldn[(airbnb_ldn['Overall Rating'] >= 2) & (airbnb_ldn['Overall Rating'] <= 2.9)]['Average Daily Rate (Native)'].mean(),
            airbnb_ldn[(airbnb_ldn['Overall Rating'] >= 3) & (airbnb_ldn['Overall Rating'] <= 3.9)]['Average Daily Rate (Native)'].mean(),
            airbnb_ldn[(airbnb_ldn['Overall Rating'] >= 4) & (airbnb_ldn['Overall Rating'] <= 4.9)]['Average Daily Rate (Native)'].mean(),
            airbnb_ldn[(airbnb_ldn['Overall Rating'] == 5)]['Average Daily Rate (Native)'].mean()
            ]
            
plt.plot(X_values, y_values, color='yellow')
plt.xlabel('Overall Rating Range')
plt.ylabel('Average Daily Rental Rate, £')
plt.title('Average Daily Rental Rates Against Property Overall Rating')
plt.show()

# %%
y_rating_quantities = [len(airbnb_ldn[(airbnb_ldn['Overall Rating'] >= 1) & (airbnb_ldn['Overall Rating'] <= 1.9)]),
                        len(airbnb_ldn[(airbnb_ldn['Overall Rating'] >= 2) & (airbnb_ldn['Overall Rating'] <= 2.9)]),
                        len(airbnb_ldn[(airbnb_ldn['Overall Rating'] >= 3) & (airbnb_ldn['Overall Rating'] <= 3.9)]),
                        len(airbnb_ldn[(airbnb_ldn['Overall Rating'] >= 4) & (airbnb_ldn['Overall Rating'] <= 4.9)]),
                        len(airbnb_ldn[(airbnb_ldn['Overall Rating'] == 5)].value_counts())]

plt.bar(X_values, y_rating_quantities, color = 'green')
plt.show()

# %%
len(airbnb_ldn[(airbnb_ldn['Overall Rating'] >= 4) & (airbnb_ldn['Overall Rating'] <= 4.9)])
# Out:
# 20735

# %% [markdown]
# ## EDA on the Target Column
#
# The target column is the 'Annual Revenue (LTM)' column.
#
# This column will be explored further:

# %%
print(f"The maximum yearly income of any London Airbnb property is £{airbnb_ldn['Annual Revenue LTM (Native)'].max()}.")
print(f"The minimum yearly income of any London Airbnb property is £{airbnb_ldn['Annual Revenue LTM (Native)'].min()}.")
# Out:
# The maximum yearly income of any London Airbnb property is £357897.7.
# The minimum yearly income of any London Airbnb property is £6.3.

# %%
plt.figure()
plt.hist(airbnb_ldn['Annual Revenue LTM (Native)'], bins=1000)
plt.xlabel('London Airbnb Yearly LTM')
plt.ylabel('Quantity of Occurances')
plt.show()

# %%
# Log scale all columns, add 1 to avoid taking the log of 0
y_log = np.log(y + 1)

# %%
# Plot the same graph but using a 'log' scale on the x-axis, to see how this alteres/improves the distribution
plt.figure()
plt.hist(y_log, bins=1000)
plt.xlabel('London Airbnb Yearly LTM (log)')
plt.ylabel('Quantity of Occurances')
plt.title('Log Graph for Annual Revenue')
plt.xscale('log')
plt.show()

# %% [markdown]
# The 'log' tranformed graph shows a more normally distributed pattern (slightly left-skewed).
#
# **Complete now but will require re-ordering prior to submission**

# %%
airbnb_ldn.head().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 38 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Listing Title                                      5 non-null      object
#  1   Property Type                                      5 non-null      object
#  2   Listing Type                                       5 non-null      object
#  3   City                                               5 non-null      object
#  4   Zipcode                                            5 non-null      object
#  5   Number of Reviews                                  5 non-null      int64
#  6   Bedrooms                                           5 non-null      object
#  7   Bathrooms                                          5 non-null      int64
#  8   Max Guests                                         5 non-null      int64
#  9   Airbnb Superhost                                   5 non-null      object
#  10  Cancellation Policy                                3 non-null      object
#  11  Cleaning Fee (Native)                              5 non-null      float64
#  12  Extra People Fee(Native)                           5 non-null      float64
#  13  Check-in Time                                      5 non-null      object
#  14  Checkout Time                                      5 non-null      object
#  15  Minimum Stay                                       5 non-null      int64
#  16  Latitude                                           5 non-null      float64
#  17  Longitude                                          5 non-null      float64
#  18  Overall Rating                                     5 non-null      float64
#  19  Airbnb Communication Rating                        5 non-null      float64
#  20  Airbnb Accuracy Rating                             5 non-null      float64
#  21  Airbnb Cleanliness Rating                          5 non-null      float64
#  22  Airbnb Checkin Rating                              5 non-null      float64
#  23  Airbnb Location Rating                             5 non-null      float64
#  24  Airbnb Value Rating                                5 non-null      float64
#  25  Amenities                                          5 non-null      object
#  26  Airbnb Host ID                                     5 non-null      int64
#  27  Host Listing Count                                 3 non-null      float64
#  28  guest_controls                                     5 non-null      object
#  29  Pets Allowed                                       5 non-null      bool
#  30  Count Available Days LTM                           5 non-null      int64
#  31  Count Blocked Days LTM                             5 non-null      int64
#  32  Count Reservation Days LTM                         5 non-null      int64
#  33  Occupancy Rate LTM                                 5 non-null      int64
#  34  Number of Bookings LTM                             5 non-null      int64
#  35  Number of Bookings LTM - Number of observed month  5 non-null      int64
#  36  Average Daily Rate (Native)                        5 non-null      float64
#  37  Annual Revenue LTM (Native)                        5 non-null      float64
# dtypes: bool(1), float64(14), int64(11), object(12)
# memory usage: 1.6+ KB

# %%
num_cols = airbnb_ldn.select_dtypes(include=['int', 'float64'])
num_cols.head().T
# Out:
#                                                               0             1  \
# Number of Reviews                                  9.000000e+00  1.100000e+01
# Bathrooms                                          2.000000e+00  1.000000e+00
# Max Guests                                         6.000000e+00  4.000000e+00
# Cleaning Fee (Native)                              1.548000e+02  0.000000e+00
# Extra People Fee(Native)                           0.000000e+00  0.000000e+00
# Minimum Stay                                       3.000000e+00  1.000000e+00
# Latitude                                           5.143105e+01  5.143399e+01
# Longitude                                         -2.607400e-01 -2.565600e-01
# Overall Rating                                     4.100000e+00  4.800000e+00
# Airbnb Communication Rating                        9.000000e+00  1.000000e+01
# Airbnb Accuracy Rating                             8.000000e+00  9.000000e+00
# Airbnb Cleanliness Rating                          8.000000e+00  1.000000e+01
# Airbnb Checkin Rating                              9.000000e+00  1.000000e+01
# Airbnb Location Rating                             8.000000e+00  9.000000e+00
# Airbnb Value Rating                                8.000000e+00  1.000000e+01
# Airbnb Host ID                                     9.105043e+07  4.769140e+08
# Host Listing Count                                 4.000000e+00           NaN
# Count Available Days LTM                           1.000000e+01  1.630000e+02
# Count Blocked Days LTM                             3.550000e+02  2.020000e+02
# Count Reservation Days LTM                         5.000000e+00  9.100000e+01
# Occupancy Rate LTM                                 4.000000e+01  6.700000e+01
# Number of Bookings LTM                             1.000000e+00  2.600000e+01
# Number of Bookings LTM - Number of observed month  0.000000e+00  2.300000e+01
# Average Daily Rate (Native)                        2.441000e+02  1.533000e+02
# Annual Revenue LTM (Native)                        1.619500e+03  1.673770e+04
#
#                                                               2             3  \
# Number of Reviews                                  1.000000e+00  2.000000e+01
# Bathrooms                                          2.000000e+00  1.000000e+00
# Max Guests                                         3.000000e+00  4.000000e+00
# Cleaning Fee (Native)                              0.000000e+00  3.480000e+01
# Extra People Fee(Native)                           0.000000e+00  2.500000e+00
# Minimum Stay                                       7.000000e+00  5.000000e+00
# Latitude                                           5.143500e+01  5.143531e+01
# Longitude                                         -2.570000e-01 -2.564800e-01
# Overall Rating                                     5.000000e+00  4.800000e+00
# Airbnb Communication Rating                        1.000000e+01  1.000000e+01
# Airbnb Accuracy Rating                             8.000000e+00  1.000000e+01
# Airbnb Cleanliness Rating                          1.000000e+01  9.000000e+00
# Airbnb Checkin Rating                              1.000000e+01  1.000000e+01
# Airbnb Location Rating                             8.000000e+00  9.000000e+00
# Airbnb Value Rating                                1.000000e+01  9.000000e+00
# Airbnb Host ID                                     2.098554e+07  6.591129e+07
# Host Listing Count                                          NaN  4.000000e+00
# Count Available Days LTM                           7.400000e+01  1.380000e+02
# Count Blocked Days LTM                             2.910000e+02  2.270000e+02
# Count Reservation Days LTM                         1.000000e+00  1.080000e+02
# Occupancy Rate LTM                                 2.000000e+00  9.400000e+01
# Number of Bookings LTM                             0.000000e+00  1.300000e+01
# Number of Bookings LTM - Number of observed month -2.000000e+00  8.000000e+00
# Average Daily Rate (Native)                        2.331000e+02  9.480000e+01
# Annual Revenue LTM (Native)                        3.452000e+02  1.285330e+04
#
#                                                               4
# Number of Reviews                                  0.000000e+00
# Bathrooms                                          1.000000e+00
# Max Guests                                         2.000000e+00
# Cleaning Fee (Native)                              0.000000e+00
# Extra People Fee(Native)                           0.000000e+00
# Minimum Stay                                       5.000000e+00
# Latitude                                           5.143532e+01
# Longitude                                         -2.541300e-01
# Overall Rating                                     4.000000e+00
# Airbnb Communication Rating                        1.000000e+01
# Airbnb Accuracy Rating                             1.000000e+01
# Airbnb Cleanliness Rating                          6.000000e+00
# Airbnb Checkin Rating                              1.000000e+01
# Airbnb Location Rating                             9.000000e+00
# Airbnb Value Rating                                9.000000e+00
# Airbnb Host ID                                     4.350839e+06
# Host Listing Count                                 0.000000e+00
# Count Available Days LTM                           0.000000e+00
# Count Blocked Days LTM                             3.650000e+02
# Count Reservation Days LTM                         0.000000e+00
# Occupancy Rate LTM                                 5.500000e+01
# Number of Bookings LTM                             0.000000e+00
# Number of Bookings LTM - Number of observed month  6.000000e+00
# Average Daily Rate (Native)                        4.420000e+01
# Annual Revenue LTM (Native)                        2.678000e+02

# %%
cat_cols = airbnb_ldn.select_dtypes(include='object')
cat_cols.head().T
# Out:
#                                                                      0  \
# Listing Title                        Cozy 2BR house with a garden view
# Property Type                                              Entire home
# Listing Type                                               entire_home
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             2
# Airbnb Superhost                                                     f
# Cancellation Policy                        strict_14_with_grace_period
# Check-in Time                                      12:00 PM - 12:00 AM
# Checkout Time                                                 10:00 AM
# Amenities            ['Free parking on premises', 'Air conditioning...
# guest_controls       {"allows_children": true, "allows_infants": tr...
#
#                                                                      1  \
# Listing Title          GuestReady - Amazing home with a private garden
# Property Type                                              Entire home
# Listing Type                                               entire_home
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             2
# Airbnb Superhost                                                     t
# Cancellation Policy                                                NaN
# Check-in Time                                       3:00 PM - 12:00 AM
# Checkout Time                                                 11:00 AM
# Amenities            ['Wifi', 'Kitchen', 'Dryer', 'Dedicated worksp...
# guest_controls       {"allows_children": true, "allows_infants": tr...
#
#                                                                      2  \
# Listing Title                            Cosy cottage on Richmond Park
# Property Type                                              Entire home
# Listing Type                                               entire_home
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             1
# Airbnb Superhost                                                     f
# Cancellation Policy                                                NaN
# Check-in Time                                            After 3:00 PM
# Checkout Time                                                 11:00 AM
# Amenities            ['Free parking on premises', 'Air conditioning...
# guest_controls       {"allows_children": false, "allows_infants": f...
#
#                                                                      3  \
# Listing Title        Entire Flat. Free parking, Garden , Richmond park
# Property Type                                       Entire rental unit
# Listing Type                                               entire_home
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             2
# Airbnb Superhost                                                     f
# Cancellation Policy                        strict_14_with_grace_period
# Check-in Time                                       3:00 PM - 11:00 PM
# Checkout Time                                                 11:00 AM
# Amenities            ['Free parking on premises', 'Wifi', 'Kitchen'...
# guest_controls       {"allows_children": true, "allows_infants": tr...
#
#                                                                      4
# Listing Title         Maisonette inbetween Richmond Park and Wimbledon
# Property Type                              Private room in rental unit
# Listing Type                                              private_room
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             1
# Airbnb Superhost                                                     f
# Cancellation Policy                        strict_14_with_grace_period
# Check-in Time                                      12:00 PM - 10:00 PM
# Checkout Time                                                 11:00 AM
# Amenities            ['Free parking on premises', 'Wifi', 'Breakfas...
# guest_controls       {"allows_children": false, "allows_infants": f...

# %% [markdown]
# A lot of the columns are skewed (both left and right). A 'log' transformation can be used, to produce more normally distributed graphs for each of the numerical columns:
#
# 'Longitude', 'Latitude' and 'Number of Bookings LTM - Number of observed month' are being omitted as they all have negative values and therefore cannot be

# %%
# Log scale all columns, add 1 to avoid taking the log of 0
num_cols_log = np.log(num_cols.drop(columns = ['Longitude', 'Latitude', 'Number of Bookings LTM - Number of observed month']) + 1)

# %%
# create a subplots structure with 4 columns and 5 rows
cols = 4
rows = len(num_cols_log.columns)//cols + 1

plt.figure(figsize=(17, 20))
plt.tight_layout()
plt.subplots_adjust(hspace = 1)
plt.suptitle('Log-Transformed Variable Distributions', y=0.92)

for i, column in enumerate(num_cols_log.columns):
    ax = plt.subplot(rows, cols, i+1)
    ax.set_title(f"Feature: {column}", size=10)
    ax.hist(num_cols_log[column], bins=100, color='darkgreen')

plt.show()

# %% [markdown]
# There are negative values on the 'Number of Bookings LTM - Number of observed month' column. This is peculiar, as the my initial assumption was that all the values on this column should be positive, with zero being the minimum value. This will be investigated further.

# %%
airbnb_ldn['Number of Bookings LTM - Number of observed month'].min()
# Out:
# -11

# %%
plt.figure()
plt.hist(airbnb_ldn['Number of Bookings LTM - Number of observed month'])
plt.show()

# %%
airbnb_ldn[airbnb_ldn['Number of Bookings LTM - Number of observed month'] == -11]
# Out:
#                                            Listing Title  \
# 1051   5 Bedroom Mews house,quiet, green & New in Che...
# 3038     3 Boutique Apartments , close to Central London
# 4810   Female only,comfortable,clean double room.  Lo...
# 6835     Modern 1 Bedroom Apartment near Hampstead Heath
# 8371     Pied A Terre in Spitalfields   One bedroom flat
# ...                                                  ...
# 31941       Cosy Single Room for Female in Charming Home
# 32006      Homely Double in Abbey Wood, Garden + Parking
# 32298                           Portway Gem in Stratford
# 32445               Nice Small single room for 1 guest .
# 32546                     2 bed apartment by the seaside
#
#                    Property Type  Listing Type            City Zipcode  \
# 1051                 Entire home   entire_home          London   SW5 9
# 3038          Entire rental unit   entire_home  Greater London  SE17 1
# 4810   Private room in townhouse  private_room  Greater London  NW10 3
# 6835            Entire apartment   entire_home  Greater London   NW3 2
# 8371          Entire rental unit   entire_home  Greater London    E1 6
# ...                          ...           ...             ...     ...
# 31941      Private room in house  private_room          London  SE18 1
# 32006       Private room in home  private_room  Greater London   SE2 9
# 32298           Entire apartment   entire_home  Greater London   E15 3
# 32445       Private room in home  private_room  Greater London    E7 9
# 32546               Entire condo   entire_home  Greater London  SE28 0
#
#        Number of Reviews Bedrooms  Bathrooms  Max Guests Airbnb Superhost  \
# 1051                   8        5          3          10                f
# 3038                   0   Studio          1           3                f
# 4810                   0        1          1           2                t
# 6835                   0        1          1           3                f
# 8371                   5        1          1           2                f
# ...                  ...      ...        ...         ...              ...
# 31941                  0        1          2           1                f
# 32006                  0        1          1           2                f
# 32298                  0        1          1           2                f
# 32445                  1        1          1           1                t
# 32546                  4        2          2           4                f
#
#        ...                                     guest_controls  Pets Allowed  \
# 1051   ...  {"allows_children": true, "allows_infants": tr...         False
# 3038   ...  {"allows_children": true, "allows_infants": tr...         False
# 4810   ...  {"allows_children": false, "allows_infants": f...         False
# 6835   ...  {"allows_children": true, "allows_infants": tr...         False
# 8371   ...  {"allows_children": false, "allows_infants": f...         False
# ...    ...                                                ...           ...
# 31941  ...  {"allows_children": false, "allows_infants": f...         False
# 32006  ...  {"allows_children": true, "allows_infants": fa...         False
# 32298  ...  {"allows_children": true, "allows_infants": fa...         False
# 32445  ...  {"allows_children": false, "allows_infants": f...         False
# 32546  ...  {"allows_children": true, "allows_infants": tr...         False
#
#        Count Available Days LTM Count Blocked Days LTM  \
# 1051                         31                    334
# 3038                         73                    292
# 4810                          7                    358
# 6835                         35                    330
# 8371                         55                    310
# ...                         ...                    ...
# 31941                        31                    334
# 32006                        31                    334
# 32298                        31                    334
# 32445                        65                    300
# 32546                         1                    364
#
#       Count Reservation Days LTM  Occupancy Rate LTM  Number of Bookings LTM  \
# 1051                           7                  27                       0
# 3038                          46                  76                       0
# 4810                           4                  69                       0
# 6835                           4                  14                       0
# 8371                          11                  24                       0
# ...                          ...                 ...                     ...
# 31941                         17                  66                       0
# 32006                         13                  50                       0
# 32298                         22                  85                       0
# 32445                         52                  96                       0
# 32546                          1                 100                       0
#
#        Number of Bookings LTM - Number of observed month  \
# 1051                                                 -11
# 3038                                                 -11
# 4810                                                 -11
# 6835                                                 -11
# 8371                                                 -11
# ...                                                  ...
# 31941                                                -11
# 32006                                                -11
# 32298                                                -11
# 32445                                                -11
# 32546                                                -11
#
#        Average Daily Rate (Native)  Annual Revenue LTM (Native)
# 1051                         581.4                       4866.4
# 3038                         124.0                       6880.9
# 4810                          48.2                        233.1
# 6835                         235.4                       1153.4
# 8371                          83.0                       1094.9
# ...                            ...                          ...
# 31941                         15.8                        323.1
# 32006                         77.4                       1200.0
# 32298                        113.0                       2976.7
# 32445                         97.2                       6063.2
# 32546                        137.5                        137.5
#
# [195 rows x 38 columns]

# %%
# View rows with values less than zero:
airbnb_ldn[airbnb_ldn['Number of Bookings LTM - Number of observed month'] < 0 ]
# Out:
#                                            Listing Title  \
# 2                          Cosy cottage on Richmond Park
# 6      Friendly, clean and happy place, room for 2 pe...
# 7        Nice quiet 1 double & 1 single rooms, 3 people.
# 10         Lovely room with Door lock and free parking .
# 13     Extra Large Room, kid/pet friendly, cordial owner
# ...                                                  ...
# 32646         Modern 3 bed flat in quiet London location
# 32655                    My BRAND NEW Home is Available!
# 32668      Spacious Room Safe Location With Garden View.
# 32672  3 bedroom family house, 10 mins walk from stat...
# 32679                Comfortable bedroom in lovely house
#
#                          Property Type  Listing Type              City  \
# 2                          Entire home   entire_home    Greater London
# 6                 Private room in home  private_room    Greater London
# 7                 Private room in home  private_room    Greater London
# 10     Private room in casa particular  private_room    Greater London
# 13           Private room in townhouse  private_room    Greater London
# ...                                ...           ...               ...
# 32646               Entire rental unit   entire_home            London
# 32655             Private room in home  private_room    Greater London
# 32668             Private room in home  private_room  South Woodford,
# 32672                      Entire home   entire_home    Greater London
# 32679             Private room in home  private_room    Greater London
#
#       Zipcode  Number of Reviews Bedrooms  Bathrooms  Max Guests  \
# 2      SW15 3                  1        1          2           3
# 6       W13 9                  5        1          2           2
# 7       W13 9                  6        2          2           3
# 10     SW15 4                 11        1          1           1
# 13     SW14 7                 14        1          1           1
# ...       ...                ...      ...        ...         ...
# 32646   E11 1                 71        3          1           7
# 32655   E11 1                  2        1          1           2
# 32668   E18 1                 13        1          1           1
# 32672   E18 2                  6        2          2           5
# 32679    E4 6                 19   Studio          1           2
#
#       Airbnb Superhost  ...  \
# 2                    f  ...
# 6                    f  ...
# 7                    f  ...
# 10                   f  ...
# 13                   f  ...
# ...                ...  ...
# 32646                f  ...
# 32655                f  ...
# 32668                f  ...
# 32672                f  ...
# 32679                t  ...
#
#                                           guest_controls  Pets Allowed  \
# 2      {"allows_children": false, "allows_infants": f...         False
# 6      {"allows_children": true, "allows_infants": tr...         False
# 7      {"allows_children": true, "allows_infants": tr...         False
# 10     {"allows_children": false, "allows_infants": f...         False
# 13     {"allows_children": true, "allows_infants": tr...         False
# ...                                                  ...           ...
# 32646  {"allows_children": true, "allows_infants": tr...         False
# 32655  {"allows_children": false, "allows_infants": f...          True
# 32668  {"allows_children": false, "allows_infants": f...         False
# 32672  {"allows_children": true, "allows_infants": tr...          True
# 32679  {"allows_children": false, "allows_infants": f...         False
#
#        Count Available Days LTM Count Blocked Days LTM  \
# 2                            74                    291
# 6                            11                    354
# 7                            11                    354
# 10                            4                    361
# 13                           36                    329
# ...                         ...                    ...
# 32646                         8                    357
# 32655                        29                    336
# 32668                       211                    154
# 32672                       101                    264
# 32679                        88                    277
#
#       Count Reservation Days LTM  Occupancy Rate LTM  Number of Bookings LTM  \
# 2                              1                   2                       0
# 6                              5                  55                       1
# 7                              5                  55                       1
# 10                             2                  60                       1
# 13                            10                  59                       2
# ...                          ...                 ...                     ...
# 32646                          2                  30                       3
# 32655                          1                   4                       1
# 32668                         70                  40                       6
# 32672                         37                  44                       2
# 32679                         28                  38                       0
#
#        Number of Bookings LTM - Number of observed month  \
# 2                                                     -2
# 6                                                     -1
# 7                                                     -1
# 10                                                    -1
# 13                                                    -2
# ...                                                  ...
# 32646                                                 -7
# 32655                                                 -2
# 32668                                                 -4
# 32672                                                 -1
# 32679                                                 -3
#
#        Average Daily Rate (Native)  Annual Revenue LTM (Native)
# 2                            233.1                        345.2
# 6                             63.2                        382.4
# 7                            126.4                        764.7
# 10                            37.9                         90.9
# 13                            36.3                       1516.8
# ...                            ...                          ...
# 32646                         82.2                        351.6
# 32655                         62.4                         72.7
# 32668                         55.3                       4852.2
# 32672                        181.7                       8074.6
# 32679                         56.9                       1902.3
#
# [7427 rows x 38 columns]

# %% [markdown]
# The target column, of yearly revenue is completely dependent on the occupancy rate. The more attractive and appealing the property, the higher the occupancy rate will be and thus the higher the year revenue. Therefore, the 'occupancy rate' column, cannot necessarily be treated as a independent variable, it will most likely have some linear correlation with the yearly revenue; this will have to be addressed, with a solution being devised that optmises both elements effectively.

# %%
plt.figure(figsize=(15, 5))
sns.heatmap(num_cols.corr(), cmap="coolwarm", vmax=1.0, vmin=-1.0)
plt.show()

# %% [markdown]
# There is a large amount of correlation between various columns. In many ways, this is unsurprising. Many of the columns are directly influence on the outcome of others, such as specific review columns ultimately influencing the property overall review, columns that have reference to property availability are going to have strong correlations, as they portray similar information in different formats.
#
# These correlations must be tackled in an appropritate manner, as all independent variables must not be correlated between each other, as this can ultimately impact the final model.
#
# Look at some of the columns that seem to have very strong correlations. These will be investigated further, to determine how best to address the issue.
#
# Starting with 'Number of Bookings LTM - Number of observed month' and 'Number of Bookings LTM'.

# %%
plt.figure()
plt.scatter(airbnb_ldn['Number of Bookings LTM - Number of observed month'], airbnb_ldn['Number of Bookings LTM'])
plt.xlabel('Number of Bookings LTM - Number of observed month')
plt.ylabel('Number of Bookings LTM')
plt.title('Number of Bookings - Number of observed month, against Number of Bookings')
plt.show()

# %% [markdown]
# Looking more into the 'Occupancy Rate LTM', it can be seen that a vast proportion of the various properties have a occupancy rate of 100%. This will be investiagated further:

# %%
plt.figure()
plt.hist(airbnb_ldn['Occupancy Rate LTM'], bins=100)
plt.title('Occupancy Rate LTM - Histogram')
plt.show()

# %% [markdown]
# finding the percentage of properties that have an occupancy rate of 100%:

# %%
print(f"The percentage of rows on the dataframe where the yearly occupancy rate is 100% for the last twelve months is {round(len(airbnb_ldn[airbnb_ldn['Occupancy Rate LTM'] == 100])/len(airbnb_ldn)*100, 2)}%.")
# Out:
# The percentage of rows on the dataframe where the yearly occupancy rate is 100% for the last twelve months is 22.03%.

# %% [markdown]
# The impact the 'Occupancy Rate LTM' column has on the 'Annual Revenue LTM' will now be determined:

# %%
plt.figure()
plt.scatter(airbnb_ldn['Occupancy Rate LTM'], airbnb_ldn['Annual Revenue LTM (Native)'], color = 'orange')
plt.xlabel('Occupancy Rate (LTM)')
plt.ylabel('Annual Revenue (£)')
plt.title('Property Annual Revenue against the Occupancy Rate')
plt.show()

# %% [markdown]
# There does seem to be some positive trend between the annual revenue and the occupancy rate, but there are some unexpected results. There seems to be a significant number of properties that have a occupany rate of 100%, but an Annual Revenue of £0.
#
# This seems odd and unless the properties charge £0 rent, then this shouldn't be possible. This will be explored further.

# %%
airbnb_ldn[(airbnb_ldn['Annual Revenue LTM (Native)'] <= 100) & (airbnb_ldn['Occupancy Rate LTM'] >= 90)]
# Out:
#                                            Listing Title  \
# 543     Welcoming room in friendly Hammersmith near Tube
# 562                          Nice Room in Central London
# 1271               Large one bedroom flat in Wandsworth.
# 1407             Spacious Double Bedroom in Clapham Park
# 3432                     Zen London Studio Private Space
# 6930   Compact En-Suite Studio With Kitchenette In Ca...
# 7268    Shared room near tube (garden view)(female only)
# 8615           Modern Bright Double Room in King's Cross
# 8937        Green Islington Private Double Room + Garden
# 9294             Room with panoramic view in Whitechapel
# 9417                 Villa Pamilla: the James Bond suite
# 9598                 Private room in co-living Apartment
# 9624               Stylish private room with living area
# 11576                   Double Room in Wimbledon Village
# 13014             Charming double room in penthouse flat
# 13143   Big, Beautiful, Sunny, West Kensington TWIN Room
# 13716                                          Cosy room
# 14779    One bedroom Fulham apartment with large balcony
# 19308                   Уютная комната в центре Лондона.
# 19837       Modern 1BD Flat with Balcony in Surrey Quays
# 24824              Private Double Room in St John’s Wood
# 27264      BRIGHT ROOM WITH BALCONY - LONG STAYS WELCOME
# 29424  Colourful 1 BD + Balcony in Vibrant Bethnal Green
# 29922                                      Victoria Park
# 30044                 Lovely room in Clapton, Hackney E5
# 30547                 Spacious room in lovely Crouch End
#
#                            Property Type  Listing Type            City  \
# 543    Private room in bed and breakfast  private_room  Greater London
# 562          Private room in rental unit  private_room  Greater London
# 1271                    Entire apartment   entire_home  Greater London
# 1407               Private room in condo  private_room  Greater London
# 3432                        Entire condo   entire_home  Greater London
# 6930           Entire serviced apartment   entire_home  Greater London
# 7268          Shared room in rental unit   shared_room  Greater London
# 8615         Private room in rental unit  private_room  Greater London
# 8937         Private room in rental unit  private_room  Greater London
# 9294         Private room in rental unit  private_room  Greater London
# 9417     Private room in casa particular  private_room  Greater London
# 9598         Private room in rental unit  private_room  Greater London
# 9624         Private room in rental unit  private_room  Greater London
# 11576              Private room in condo  private_room  Greater London
# 13014        Private room in rental unit  private_room          London
# 13143          Private room in townhouse  private_room  Greater London
# 13716        Private room in rental unit  private_room  Greater London
# 14779                 Entire rental unit   entire_home  Greater London
# 19308        Private room in rental unit  private_room  Greater London
# 19837                       Entire condo   entire_home  Greater London
# 24824        Private room in rental unit  private_room  Greater London
# 27264        Private room in rental unit  private_room  Greater London
# 29424                       Entire condo   entire_home  Greater London
# 29922                 Entire rental unit   entire_home  Greater London
# 30044        Private room in rental unit  private_room          London
# 30547        Private room in rental unit  private_room  Greater London
#
#       Zipcode  Number of Reviews Bedrooms  Bathrooms  Max Guests  \
# 543      W6 0                  4        1          1           1
# 562      W6 8                  3        1          1           2
# 1271   SW18 2                  2        1          1           2
# 1407    SW2 5                 45        1          1           2
# 3432    SE6 1                  1   Studio          1           2
# 6930    NW1 8                  2        1          1           2
# 7268    NW9 5                  3        1          1           1
# 8615     N1 0                 15        1          1           2
# 8937     N1 3                 13        1          2           1
# 9294     E1 3                  3        1          1           1
# 9417     E3 5                  3        1          3           2
# 9598     E3 4                  1        1          1           1
# 9624     E3 2                  1        1          1           2
# 11576  SW19 7                  1        1          1           2
# 13014   SW6 1                 20        1          1           1
# 13143   W14 9                 75        1          1           2
# 13716   SW5 9                  8        1          1           1
# 14779   SW6 2                 21        1          1           2
# 19308  SE15 3                  5        1          1           2
# 19837   SE8 3                  5        1          1           2
# 24824   NW8 0                  1        1          1           2
# 27264    E1 1                 14        1          1           2
# 29424    E2 0                  2        1          2           2
# 29922    E3 5                 13        2          1           4
# 30044    E5 0                 66        1          1           2
# 30547    N8 9                  5        1          1           2
#
#       Airbnb Superhost  ...  \
# 543                  f  ...
# 562                  f  ...
# 1271                 f  ...
# 1407                 f  ...
# 3432                 f  ...
# 6930                 f  ...
# 7268                 f  ...
# 8615                 f  ...
# 8937                 t  ...
# 9294                 f  ...
# 9417                 f  ...
# 9598                 f  ...
# 9624                 t  ...
# 11576                f  ...
# 13014                f  ...
# 13143                f  ...
# 13716                f  ...
# 14779                f  ...
# 19308                f  ...
# 19837                f  ...
# 24824                f  ...
# 27264                f  ...
# 29424                f  ...
# 29922                f  ...
# 30044                f  ...
# 30547                f  ...
#
#                                           guest_controls  Pets Allowed  \
# 543    {"allows_children": false, "allows_infants": f...         False
# 562    {"allows_children": true, "allows_infants": tr...         False
# 1271   {"allows_children": true, "allows_infants": fa...         False
# 1407   {"allows_children": true, "allows_infants": tr...          True
# 3432   {"allows_children": false, "allows_infants": f...         False
# 6930   {"allows_children": false, "allows_infants": f...         False
# 7268   {"allows_children": true, "allows_infants": tr...         False
# 8615   {"allows_children": false, "allows_infants": f...          True
# 8937   {"allows_children": false, "allows_infants": f...          True
# 9294   {"allows_children": false, "allows_infants": f...         False
# 9417   {"allows_children": true, "allows_infants": fa...         False
# 9598   {"allows_children": false, "allows_infants": f...         False
# 9624   {"allows_children": false, "allows_infants": f...         False
# 11576  {"allows_children": false, "allows_infants": f...         False
# 13014  {"allows_children": true, "allows_infants": fa...         False
# 13143  {"allows_children": false, "allows_infants": f...         False
# 13716  {"allows_children": false, "allows_infants": f...         False
# 14779  {"allows_children": false, "allows_infants": f...         False
# 19308  {"allows_children": true, "allows_infants": fa...         False
# 19837  {"allows_children": true, "allows_infants": fa...         False
# 24824  {"allows_children": false, "allows_infants": f...         False
# 27264  {"allows_children": false, "allows_infants": f...         False
# 29424  {"allows_children": true, "allows_infants": fa...         False
# 29922  {"allows_children": true, "allows_infants": tr...          True
# 30044  {"allows_children": false, "allows_infants": f...         False
# 30547  {"allows_children": false, "allows_infants": f...          True
#
#        Count Available Days LTM Count Blocked Days LTM  \
# 543                           1                    364
# 562                           1                    364
# 1271                          1                    364
# 1407                          2                    363
# 3432                          1                    364
# 6930                          1                    364
# 7268                          4                    361
# 8615                          4                    361
# 8937                          0                    365
# 9294                          8                    357
# 9417                          1                    364
# 9598                         32                    333
# 9624                          1                    364
# 11576                         1                    364
# 13014                         1                    364
# 13143                         1                    364
# 13716                         1                    364
# 14779                         1                    364
# 19308                         1                    364
# 19837                         1                    364
# 24824                         1                    364
# 27264                         4                    361
# 29424                         1                    364
# 29922                         1                    364
# 30044                         1                    364
# 30547                         1                    364
#
#       Count Reservation Days LTM  Occupancy Rate LTM  Number of Bookings LTM  \
# 543                            1                 100                       1
# 562                            1                 100                       0
# 1271                           1                 100                       0
# 1407                           2                 100                       3
# 3432                           1                 100                       0
# 6930                           1                 100                       0
# 7268                           3                  90                       0
# 8615                           3                  90                       0
# 8937                           0                 100                       1
# 9294                           8                 100                       0
# 9417                           1                 100                       3
# 9598                          32                 100                       0
# 9624                           1                 100                       9
# 11576                          1                 100                       1
# 13014                          1                 100                       5
# 13143                          1                 100                       0
# 13716                          1                 100                       0
# 14779                          1                 100                       1
# 19308                          1                 100                       3
# 19837                          1                 100                       4
# 24824                          1                 100                       0
# 27264                          4                 100                       1
# 29424                          1                 100                       0
# 29922                          1                 100                       2
# 30044                          1                 100                       2
# 30547                          1                 100                       3
#
#        Number of Bookings LTM - Number of observed month  \
# 543                                                   -1
# 562                                                   -1
# 1271                                                 -10
# 1407                                                  -7
# 3432                                                  -2
# 6930                                                  -2
# 7268                                                   0
# 8615                                                   1
# 8937                                                  -4
# 9294                                                  -2
# 9417                                                  -1
# 9598                                                  -2
# 9624                                                   7
# 11576                                                 -2
# 13014                                                  2
# 13143                                                -10
# 13716                                                -10
# 14779                                                 -2
# 19308                                                  0
# 19837                                                  1
# 24824                                                 -3
# 27264                                                 -2
# 29424                                                 -3
# 29922                                                 -8
# 30044                                                 -8
# 30547                                                 -7
#
#        Average Daily Rate (Native)  Annual Revenue LTM (Native)
# 543                           49.8                         49.8
# 562                           60.0                         60.0
# 1271                          84.5                         84.5
# 1407                          37.9                         75.8
# 3432                          71.9                         71.9
# 6930                          79.0                         79.0
# 7268                          22.1                         79.8
# 8615                          27.7                         99.5
# 8937                          60.8                         60.8
# 9294                           0.8                          6.3
# 9417                          84.5                         84.5
# 9598                           0.8                         25.3
# 9624                          86.1                         86.1
# 11576                         90.1                         90.1
# 13014                         74.3                         74.3
# 13143                         64.8                         64.8
# 13716                         49.0                         49.0
# 14779                         69.5                         69.5
# 19308                         45.8                         45.8
# 19837                         86.1                         86.1
# 24824                          7.9                          7.9
# 27264                         14.2                         83.0
# 29424                         55.3                         55.3
# 29922                         85.3                         85.3
# 30044                         52.1                         52.1
# 30547                         41.1                         41.1
#
# [26 rows x 38 columns]

# %% [markdown]
# ## Target Column Analysis
#
# Looking at the target column 'Annual Revenue LTM (Native), several of the other numerical columns will be compared to determine their correlations.
#
# Initially, looking at the 'Occupancy Rate LTM', this column should be strongly correlated with the target column. In theory, a property with a very high occupancy rate, should have a high yearly revenue.

# %%
# Determine the correlation between the Annual Revenue and the Occupancy Rate:
airbnb_ldn['Annual Revenue LTM (Native)'].corr(airbnb_ldn['Occupancy Rate LTM'])
# Out:
# 0.22314762920999018

# %%
plt.figure()
plt.scatter(airbnb_ldn['Occupancy Rate LTM'], airbnb_ldn['Annual Revenue LTM (Native)'])
plt.xlabel('Occupancy Rate LTM')
plt.ylabel('Annual Revenue')
plt.title('Property Annual Revenue against Occupancy Rate LTM')
plt.show()

# %% [markdown]
# There is a fairly low correlation between the occupany rate and the Annual Revenue. This is slightly unexpected, but can be explained. As previously determined, the mean value for the average occupancy rate is 72%.

# %%
print(f"Over a third ({round(len(airbnb_ldn[airbnb_ldn['Occupancy Rate LTM'] >=90 ])/len(airbnb_ldn)*100,2)}%), have an occcupancy rate of 90% or more.")
# Out:
# Over a third (34.64%), have an occcupancy rate of 90% or more.

# %% [markdown]
# As the occupancy rate on average is high, with a left-skewed distribution, the correlation between the occupany rate and Annual Revenue is not significant. As most properties have a high revenue regardless, the amount of daily rent charged and subsequent Annual Revnue, is not massively effected by a the occupancy rate. Looking at the scatter graph, the properties that make have the highest Annual income for their respectivie occupancy Rate (LTM) do show some positive trend, but the large quantity of properties that seem to make very little, regardless of their occupancy rate, reduce the overall correlations.

# %%
num_cols = airbnb_ldn.select_dtypes(exclude='object')

# %%
num_cols.drop(columns ='Annual Revenue LTM (Native)', inplace=True)

# %%
y = airbnb_ldn['Annual Revenue LTM (Native)']

# %%
y
# Out:
# 0         1619.5
# 1        16737.7
# 2          345.2
# 3        12853.3
# 4          267.8
#           ...
# 32681     5371.2
# 32682      189.6
# 32683     6335.8
# 32684     4264.4
# 32685     6596.5
# Name: Annual Revenue LTM (Native), Length: 32686, dtype: float64

# %%
for cols in num_cols.columns:
    plt.figure()
    plt.scatter(num_cols[cols], y)
    plt.xlabel(cols)
    plt.ylabel('Annual Revenue LTM')
    plt.show()
