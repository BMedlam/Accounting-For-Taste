# %% [markdown]
# # Capstone Workbook 5: Advanced Modelling

# %%
# Import libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
import statsmodels.api as sm

# %%
# Import data 
airbnb_ldn = pd.read_csv('airbnb_ldn_pp.csv')

# %%
# drop 'Unnamed: 0'
airbnb_ldn = airbnb_ldn.drop(columns = 'Unnamed: 0')

# %% [markdown]
# Split the columns to view just those with the object datatype, keeping the target column:

# %%
X_obj = airbnb_ldn.select_dtypes(include='object')
X_obj = pd.concat([X_obj, airbnb_ldn['Annual Revenue LTM (Native)']], axis=1)

# %%
X_obj
# Out:
#                                            Listing Title  \
# 0                      Cozy 2BR house with a garden view
# 1        GuestReady - Amazing home with a private garden
# 2                          Cosy cottage on Richmond Park
# 3      Entire Flat. Free parking, Garden , Richmond park
# 4       Maisonette inbetween Richmond Park and Wimbledon
# ...                                                  ...
# 32673              Service  Apartment- London Thamesmead
# 32674     Large Double Room with Free Parking and Garden
# 32675                 Forest view room in welcoming home
# 32676        Spacious Double Room with En-suite bathroom
# 32677  Large Room & Bathroom close to Forest and Station
#
#                      Property Type            City Zipcode  \
# 0                      Entire home  Greater London  SW15 3
# 1                      Entire home  Greater London  SW15 3
# 2                      Entire home  Greater London  SW15 3
# 3               Entire rental unit  Greater London  SW15 3
# 4      Private room in rental unit  Greater London  SW15 3
# ...                            ...             ...     ...
# 32673                 Entire condo  Greater London  SE28 8
# 32674         Private room in home  Greater London  SE28 8
# 32675         Private room in home  Greater London    E4 6
# 32676         Private room in home          London    E4 6
# 32677         Private room in home  Greater London    E4 6
#
#              Check-in Time                                          Amenities  \
# 0      12:00 PM - 12:00 AM  ['Free parking on premises', 'Air conditioning...
# 1       3:00 PM - 12:00 AM  ['Wifi', 'Kitchen', 'Dryer', 'Dedicated worksp...
# 2            After 3:00 PM  ['Free parking on premises', 'Air conditioning...
# 3       3:00 PM - 11:00 PM  ['Free parking on premises', 'Wifi', 'Kitchen'...
# 4      12:00 PM - 10:00 PM  ['Free parking on premises', 'Wifi', 'Breakfas...
# ...                    ...                                                ...
# 32673    3:00 PM - 9:00 PM  ['Free parking on premises', 'Wifi', 'Kitchen'...
# 32674    2:00 PM - 4:00 PM  ['Free parking on premises', 'Wifi', 'Kitchen'...
# 32675                  NaN  ['Wifi', 'Kitchen', 'Hair dryer', 'TV', 'Iron'...
# 32676   3:00 PM - 10:00 PM  ['Wifi', 'Kitchen', 'Hair dryer', 'TV', 'Iron'...
# 32677   3:00 PM - 10:00 PM  ['Free parking on premises', 'Wifi', 'Kitchen'...
#
#                                           guest_controls  \
# 0      {"allows_children": true, "allows_infants": tr...
# 1      {"allows_children": true, "allows_infants": tr...
# 2      {"allows_children": false, "allows_infants": f...
# 3      {"allows_children": true, "allows_infants": tr...
# 4      {"allows_children": false, "allows_infants": f...
# ...                                                  ...
# 32673  {"allows_children": true, "allows_infants": tr...
# 32674  {"allows_children": true, "allows_infants": tr...
# 32675  {"allows_children": true, "allows_infants": fa...
# 32676  {"allows_children": false, "allows_infants": f...
# 32677  {"allows_children": false, "allows_infants": f...
#
#        Annual Revenue LTM (Native)
# 0                           1619.5
# 1                          16737.7
# 2                            345.2
# 3                          12853.3
# 4                            267.8
# ...                            ...
# 32673                       5371.2
# 32674                        189.6
# 32675                       6335.8
# 32676                       4264.4
# 32677                       6596.5
#
# [32678 rows x 8 columns]

# %%
# confirm datatype of remaining columns:
X_obj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32678 entries, 0 to 32677
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Listing Title                32674 non-null  object
#  1   Property Type                32678 non-null  object
#  2   City                         32678 non-null  object
#  3   Zipcode                      32678 non-null  object
#  4   Check-in Time                30921 non-null  object
#  5   Amenities                    32678 non-null  object
#  6   guest_controls               32678 non-null  object
#  7   Annual Revenue LTM (Native)  32678 non-null  float64
# dtypes: float64(1), object(7)
# memory usage: 2.0+ MB

# %% [markdown]
# Now the object datatype columns have been isolated with the target column, the data will be checked:

# %%
# check for nulls
X_obj.isnull().sum()
# Out:
# Listing Title                     4
# Property Type                     0
# City                              0
# Zipcode                           0
# Check-in Time                  1757
# Amenities                         0
# guest_controls                    0
# Annual Revenue LTM (Native)       0
# dtype: int64

# %% [markdown]
# The 'Check-in Time' column has many nulls. This column isn't essential for the model, so it can be dropped for the time being.
# The 'Listing Title' column has 4 null values. This is insignificant compared to the entire dataset size, so these rows can be dropped.

# %%
# dropping Check-in time column
X_obj.drop(columns='Check-in Time', inplace=True)

# %%
# dropping the Listing Title null rows:
X_obj.dropna(inplace=True)

# %%
# sanity check
X_obj.isnull().sum()
# Out:
# Listing Title                  0
# Property Type                  0
# City                           0
# Zipcode                        0
# Amenities                      0
# guest_controls                 0
# Annual Revenue LTM (Native)    0
# dtype: int64

# %% [markdown]
# As seen, there are no null values remaining.
#
# The independent and dependent variables can now be split.

# %%
X = X_obj.drop(columns='Annual Revenue LTM (Native)')

# %%
y = X_obj['Annual Revenue LTM (Native)']

# %% [markdown]
# ### Complete a Train-Test Split for the NLP to Take Place

# %%
# required imports 
from sklearn.model_selection import train_test_split

# %%
# split independent and target data between train and test sets:
X_train, X_test, y_train, y_test = train_test_split(X_obj, y, test_size = 0.25, random_state=42)

# %%
# reset index for train test split data:
X_train.reset_index(inplace=True, drop=True)
X_test.reset_index(inplace=True, drop=True)
y_train.reset_index(inplace=True, drop=True)
y_test.reset_index(inplace=True, drop=True)

# %% [markdown]
# ## Starting With Listing Title

# %%
lt_array = X_train['Listing Title']

# %%
lt_array
# Out:
# 0                   Amazing 2 bedroom apartment in Chelsea
# 1                        Double Room for two in Kensington
# 2                          Huge double room in Hammersmith
# 3           Superbly located 2 bed flat with garden office
# 4        Amazing Entire Flat in Heart of London/ Piccad...
#                                ...
# 24500    Penthouse Room with Views over Park, near Station
# 24501    Newly Refurbished HotelStyle Apt - Central London
# 24502       Lovely central private bedroom and shower room
# 24503         Large Studio - w/Sofabed - Chelsea SW3 - NGH
# 24504                     Lovely 1bedroom-Baker St Station
# Name: Listing Title, Length: 24505, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# .1 Instantiate transformer object
bagofwords = CountVectorizer(min_df = 1000,
                             ngram_range = (1, 4))

# 2. Fit
bagofwords.fit(lt_array)

# 3. Transform
amenities_transformed = bagofwords.transform(lt_array)
amenities_transformed
# Out:
# <24505x34 sparse matrix of type '<class 'numpy.int64'>'
# 	with 76593 stored elements in Compressed Sparse Row format>

# %%
# View the words that are occuring in the Listing Title:
bagofwords.vocabulary_
# Out:
# {'bedroom': 5,
#  'apartment': 1,
#  'in': 18,
#  'apartment in': 2,
#  'double': 11,
#  'room': 27,
#  'double room': 12,
#  'room in': 28,
#  'bed': 4,
#  'flat': 13,
#  'with': 33,
#  'garden': 15,
#  'of': 24,
#  'london': 19,
#  'flat in': 14,
#  'the': 31,
#  'studio': 30,
#  'and': 0,
#  'to': 32,
#  'beautiful': 3,
#  'house': 17,
#  'home': 16,
#  'central': 8,
#  'central london': 9,
#  'bright': 7,
#  'spacious': 29,
#  'modern': 22,
#  'lovely': 20,
#  'cosy': 10,
#  'near': 23,
#  'private': 26,
#  'park': 25,
#  'luxury': 21,
#  'bedroom flat': 6}

# %%
# looking at individual text items from the 'Listing Title' column:
([x.split(':')[0] for x in X_obj['Listing Title'][0][1:].split(', ')])
# Out:
# ['ozy 2BR house with a garden view']

# %%
# determining the number of individual features in the 'guest controls' column:
len([x.split(':')[0] for x in airbnb_obj['guest_controls'][0][1:].split(', ')])
# Out:
# 40

# %%
# looking at individual text items from the 'guest_controls' column:
([x.split(':')[0] for x in airbnb_obj['guest_controls'][0][1:].split(', ')])
# Out:
# ['"allows_children"',
#  '"allows_infants"',
#  '"allows_pets"',
#  '"allows_smoking"',
#  '"allows_events"',
#  '"id"',
#  '"host_check_in_time_message"',
#  '"localized_structured_house_rules_with_tips"',
#  '"p3_structured_house_rules"',
#  '"No pets"',
#  '"No parties or events"',
#  '"Self check-in with lockbox"]',
#  '"structured_house_rules"',
#  '"No pets"',
#  '"No parties or events"]',
#  '"structured_house_rules_with_tips"',
#  '"long_term_text"',
#  '"text"',
#  '"tip"',
#  '"details"',
#  '"airmoji_key"',
#  '{"key"',
#  '"long_term_text"',
#  '"text"',
#  '"tip"',
#  '"details"',
#  '"airmoji_key"',
#  '{"key"',
#  '"long_term_text"',
#  '"text"',
#  '"tip"',
#  '"details"',
#  '"airmoji_key"',
#  '{"key"',
#  '"long_term_text"',
#  '"text"',
#  '"tip"',
#  '"details"',
#  '"airmoji_key"',
#  '"allows_non_china_users"']

# %%
# Out:
# {'bedroom': 5,
#  'apartment': 1,
#  'in': 18,
#  'apartment in': 2,
#  'double': 11,
#  'room': 27,
#  'double room': 12,
#  'room in': 28,
#  'bed': 4,
#  'flat': 13,
#  'with': 33,
#  'garden': 15,
#  'of': 24,
#  'london': 19,
#  'flat in': 14,
#  'the': 31,
#  'studio': 30,
#  'and': 0,
#  'to': 32,
#  'beautiful': 3,
#  'house': 17,
#  'home': 16,
#  'central': 8,
#  'central london': 9,
#  'bright': 7,
#  'spacious': 29,
#  'modern': 22,
#  'lovely': 20,
#  'cosy': 10,
#  'near': 23,
#  'private': 26,
#  'park': 25,
#  'luxury': 21,
#  'bedroom flat': 6}

# %% [markdown]
# ## Looking at 'Amenities' column:

# %%
airbnb_obj['Amenities']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 airbnb_obj['Amenities']
#
# NameError: name 'airbnb_obj' is not defined

# %%
airbnb_obj['Amenities'].str.split(', ')
# Out:
# 0        [['Free parking on premises', 'Air conditionin...
# 1        [['Wifi', 'Kitchen', 'Dryer', 'Dedicated works...
# 2        [['Free parking on premises', 'Air conditionin...
# 3        [['Free parking on premises', 'Wifi', 'Kitchen...
# 4        [['Free parking on premises', 'Wifi', 'Breakfa...
#                                ...
# 32673    [['Free parking on premises', 'Wifi', 'Kitchen...
# 32674    [['Free parking on premises', 'Wifi', 'Kitchen...
# 32675    [['Wifi', 'Kitchen', 'Hair dryer', 'TV', 'Iron...
# 32676    [['Wifi', 'Kitchen', 'Hair dryer', 'TV', 'Iron...
# 32677    [['Free parking on premises', 'Wifi', 'Kitchen...
# Name: Amenities, Length: 32678, dtype: object

# %%
# .1 Instantiate transformer object
bagofwords = CountVectorizer(min_df = 1000,
                             ngram_range = (1, 4))

# 2. Fit
bagofwords.fit(X_train['Amenities'])

# 3. Transform
amenities_transformed = bagofwords.transform(X_train['Amenities'])
amenities_transformed
# Out:
# <24508x852 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3974016 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Looking at the features:

# %%
bagofwords.vocabulary_
# Out:
# {'free': 417,
#  'parking': 710,
#  'on': 663,
#  'premises': 744,
#  'air': 8,
#  'conditioning': 238,
#  'wifi': 986,
#  'kitchen': 554,
#  'indoor': 517,
#  'fireplace': 403,
#  'cable': 177,
#  'tv': 939,
#  'dryer': 311,
#  'dedicated': 267,
#  'workspace': 1004,
#  'hair': 461,
#  'shampoo': 799,
#  'iron': 520,
#  'hangers': 469,
#  'washer': 953,
#  'heating': 476,
#  'essentials': 343,
#  'bathtub': 123,
#  'body': 166,
#  'soap': 847,
#  'cleaning': 196,
#  'products': 761,
#  'conditioner': 228,
#  'hot': 501,
#  'water': 963,
#  'shower': 809,
#  'gel': 438,
#  'bed': 140,
#  'linens': 585,
#  'clothing': 209,
#  'storage': 873,
#  'drying': 327,
#  'rack': 773,
#  'for': 411,
#  'extra': 378,
#  'pillows': 727,
#  'and': 56,
#  'blankets': 153,
#  'room': 789,
#  'darkening': 263,
#  'shades': 794,
#  'safe': 793,
#  'sound': 855,
#  'system': 902,
#  'babysitter': 85,
#  'recommendations': 778,
#  'board': 164,
#  'games': 437,
#  'children': 191,
#  'books': 172,
#  'toys': 932,
#  'dinnerware': 284,
#  'crib': 254,
#  'portable': 738,
#  'fans': 382,
#  'carbon': 182,
#  'monoxide': 643,
#  'alarm': 12,
#  'fire': 390,
#  'extinguisher': 363,
#  'first': 405,
#  'aid': 0,
#  'kit': 544,
#  'smoke': 837,
#  'baking': 95,
#  'sheet': 807,
#  'barbecue': 108,
#  'utensils': 952,
#  'maker': 619,
#  'coffee': 221,
#  'cooking': 246,
#  'basics': 110,
#  'dining': 272,
#  'table': 905,
#  'dishes': 285,
#  'silverware': 819,
#  'dishwasher': 292,
#  'freezer': 424,
#  'kettle': 529,
#  'machine': 618,
#  'kitchenette': 574,
#  'microwave': 629,
#  'mini': 641,
#  'fridge': 434,
#  'oven': 686,
#  'refrigerator': 779,
#  'stove': 879,
#  'toaster': 921,
#  'wine': 1002,
#  'glasses': 450,
#  'laundromat': 575,
#  'nearby': 653,
#  'private': 756,
#  'entrance': 339,
#  'bbq': 136,
#  'grill': 455,
#  'backyard': 87,
#  'outdoor': 679,
#  'furniture': 435,
#  'patio': 721,
#  'or': 671,
#  'balcony': 98,
#  'street': 898,
#  'available': 81,
#  'during': 331,
#  'stay': 859,
#  'long': 609,
#  'term': 914,
#  'stays': 863,
#  'allowed': 39,
#  'luggage': 613,
#  'dropoff': 305,
#  'lockbox': 602,
#  'free parking': 418,
#  'parking on': 714,
#  'on premises': 667,
#  'air conditioning': 9,
#  'conditioning wifi': 239,
#  'wifi kitchen': 989,
#  'kitchen indoor': 570,
#  'indoor fireplace': 518,
#  'cable tv': 178,
#  'tv dryer': 940,
#  'dryer dedicated': 312,
#  'dedicated workspace': 268,
#  'workspace hair': 1005,
#  'hair dryer': 462,
#  'dryer tv': 322,
#  'tv shampoo': 948,
#  'shampoo iron': 801,
#  'iron hangers': 521,
#  'hangers washer': 473,
#  'washer heating': 954,
#  'heating essentials': 477,
#  'essentials bathtub': 344,
#  'body soap': 167,
#  'soap cleaning': 852,
#  'cleaning products': 200,
#  'products conditioner': 765,
#  'conditioner hot': 232,
#  'hot water': 502,
#  'water shower': 983,
#  'shower gel': 810,
#  'gel bed': 442,
#  'bed linens': 141,
#  'linens clothing': 586,
#  'clothing storage': 216,
#  'storage drying': 874,
#  'drying rack': 328,
#  'rack for': 774,
#  'for clothing': 412,
#  'clothing extra': 213,
#  'extra pillows': 379,
#  'pillows and': 728,
#  'and blankets': 57,
#  'blankets room': 161,
#  'room darkening': 790,
#  'darkening shades': 264,
#  'sound system': 856,
#  'babysitter recommendations': 86,
#  'board games': 165,
#  'children books': 192,
#  'books and': 173,
#  'and toys': 74,
#  'children dinnerware': 195,
#  'portable fans': 739,
#  'fans carbon': 383,
#  'carbon monoxide': 183,
#  'monoxide alarm': 644,
#  'alarm fire': 23,
#  'fire extinguisher': 391,
#  'extinguisher first': 365,
#  'first aid': 406,
#  'aid kit': 1,
#  'kit smoke': 552,
#  'smoke alarm': 838,
#  'baking sheet': 96,
#  'barbecue utensils': 109,
#  'coffee maker': 222,
#  'maker cooking': 620,
#  'cooking basics': 247,
#  'basics dining': 111,
#  'dining table': 278,
#  'table dishes': 906,
#  'dishes and': 286,
#  'and silverware': 65,
#  'silverware dishwasher': 823,
#  'dishwasher freezer': 296,
#  'freezer hot': 425,
#  'water kettle': 971,
#  'mini fridge': 642,
#  'oven refrigerator': 687,
#  'stove toaster': 895,
#  'wine glasses': 1003,
#  'laundromat nearby': 576,
#  'private entrance': 757,
#  'bbq grill': 137,
#  'backyard outdoor': 94,
#  'outdoor furniture': 684,
#  'patio or': 722,
#  'or balcony': 672,
#  'free street': 421,
#  'street parking': 899,
#  'cleaning available': 197,
#  'available during': 82,
#  'during stay': 332,
#  'long term': 610,
#  'term stays': 915,
#  'stays allowed': 864,
#  'allowed luggage': 53,
#  'luggage dropoff': 614,
#  'dropoff allowed': 306,
#  'allowed lockbox': 49,
#  'free parking on': 419,
#  'parking on premises': 715,
#  'air conditioning wifi': 10,
#  'conditioning wifi kitchen': 240,
#  'wifi kitchen indoor': 999,
#  'kitchen indoor fireplace': 571,
#  'cable tv dryer': 179,
#  'tv dryer dedicated': 941,
#  'dryer dedicated workspace': 313,
#  'dedicated workspace hair': 269,
#  'workspace hair dryer': 1006,
#  'hair dryer tv': 466,
#  'dryer tv shampoo': 325,
#  'tv shampoo iron': 949,
#  'shampoo iron hangers': 802,
#  'iron hangers washer': 524,
#  'hangers washer heating': 474,
#  'washer heating essentials': 955,
#  'heating essentials bathtub': 478,
#  'body soap cleaning': 170,
#  'soap cleaning products': 853,
#  'cleaning products conditioner': 203,
#  'products conditioner hot': 766,
#  'conditioner hot water': 233,
#  'hot water shower': 515,
#  'water shower gel': 984,
#  'shower gel bed': 813,
#  'gel bed linens': 443,
#  'bed linens clothing': 142,
#  'linens clothing storage': 587,
#  'clothing storage drying': 217,
#  'storage drying rack': 875,
#  'drying rack for': 329,
#  'rack for clothing': 775,
#  'for clothing extra': 415,
#  'clothing extra pillows': 214,
#  'extra pillows and': 380,
#  'pillows and blankets': 729,
#  'and blankets room': 63,
#  'blankets room darkening': 162,
#  'room darkening shades': 791,
#  'children books and': 193,
#  'books and toys': 174,
#  'portable fans carbon': 740,
#  'fans carbon monoxide': 384,
#  'carbon monoxide alarm': 184,
#  'monoxide alarm fire': 646,
#  'alarm fire extinguisher': 24,
#  'fire extinguisher first': 393,
#  'extinguisher first aid': 366,
#  'first aid kit': 407,
#  'aid kit smoke': 6,
#  'kit smoke alarm': 553,
#  'coffee maker cooking': 223,
#  'maker cooking basics': 621,
#  'cooking basics dining': 248,
#  'basics dining table': 112,
#  'dining table dishes': 279,
#  'table dishes and': 907,
#  'dishes and silverware': 287,
#  'and silverware dishwasher': 68,
#  'silverware dishwasher freezer': 824,
#  'dishwasher freezer hot': 297,
#  'freezer hot water': 426,
#  'hot water kettle': 507,
#  'patio or balcony': 723,
#  'free street parking': 422,
#  'cleaning available during': 198,
#  'available during stay': 83,
#  'long term stays': 611,
#  'term stays allowed': 916,
#  'stays allowed luggage': 871,
#  'allowed luggage dropoff': 54,
#  'luggage dropoff allowed': 615,
#  'free parking on premises': 420,
#  'air conditioning wifi kitchen': 11,
#  'wifi kitchen indoor fireplace': 1000,
#  'cable tv dryer dedicated': 180,
#  'tv dryer dedicated workspace': 942,
#  'dryer dedicated workspace hair': 314,
#  'dedicated workspace hair dryer': 270,
#  'workspace hair dryer tv': 1008,
#  'hair dryer tv shampoo': 468,
#  'dryer tv shampoo iron': 326,
#  'tv shampoo iron hangers': 950,
#  'shampoo iron hangers washer': 804,
#  'iron hangers washer heating': 525,
#  'hangers washer heating essentials': 475,
#  'washer heating essentials bathtub': 956,
#  'body soap cleaning products': 171,
#  'soap cleaning products conditioner': 854,
#  'cleaning products conditioner hot': 204,
#  'products conditioner hot water': 767,
#  'conditioner hot water shower': 234,
#  'hot water shower gel': 516,
#  'water shower gel bed': 985,
#  'shower gel bed linens': 814,
#  'gel bed linens clothing': 444,
#  'bed linens clothing storage': 143,
#  'linens clothing storage drying': 588,
#  'clothing storage drying rack': 218,
#  'storage drying rack for': 876,
#  'drying rack for clothing': 330,
#  'rack for clothing extra': 777,
#  'for clothing extra pillows': 416,
#  'clothing extra pillows and': 215,
#  'extra pillows and blankets': 381,
#  'pillows and blankets room': 732,
#  'and blankets room darkening': 64,
#  'blankets room darkening shades': 163,
#  'children books and toys': 194,
#  'portable fans carbon monoxide': 741,
#  'fans carbon monoxide alarm': 385,
#  'carbon monoxide alarm fire': 186,
#  'monoxide alarm fire extinguisher': 647,
#  'alarm fire extinguisher first': 25,
#  'fire extinguisher first aid': 394,
#  'extinguisher first aid kit': 367,
#  'first aid kit smoke': 410,
#  'aid kit smoke alarm': 7,
#  'coffee maker cooking basics': 224,
#  'maker cooking basics dining': 622,
#  'cooking basics dining table': 249,
#  'basics dining table dishes': 113,
#  'dining table dishes and': 280,
#  'table dishes and silverware': 908,
#  'dishes and silverware dishwasher': 289,
#  'and silverware dishwasher freezer': 69,
#  'silverware dishwasher freezer hot': 825,
#  'dishwasher freezer hot water': 298,
#  'freezer hot water kettle': 427,
#  'cleaning available during stay': 199,
#  'long term stays allowed': 612,
#  'term stays allowed luggage': 920,
#  'stays allowed luggage dropoff': 872,
#  'allowed luggage dropoff allowed': 55,
#  'kitchen dryer': 562,
#  'essentials smoke': 356,
#  'alarm carbon': 14,
#  'alarm first': 26,
#  'kit fire': 545,
#  'extinguisher lockbox': 371,
#  'lockbox hot': 604,
#  'water bed': 964,
#  'linens microwave': 592,
#  'microwave coffee': 630,
#  'kettle toaster': 542,
#  'toaster freezer': 922,
#  'wifi kitchen dryer': 994,
#  'kitchen dryer dedicated': 563,
#  'heating essentials smoke': 486,
#  'essentials smoke alarm': 357,
#  'smoke alarm carbon': 839,
#  'alarm carbon monoxide': 15,
#  'monoxide alarm first': 648,
#  'alarm first aid': 27,
#  'aid kit fire': 2,
#  'kit fire extinguisher': 546,
#  'fire extinguisher lockbox': 397,
#  'lockbox hot water': 605,
#  'hot water bed': 503,
#  'water bed linens': 965,
#  'bed linens microwave': 146,
#  'linens microwave coffee': 593,
#  'microwave coffee maker': 631,
#  'water kettle toaster': 981,
#  'wifi kitchen dryer dedicated': 995,
#  'kitchen dryer dedicated workspace': 564,
#  'washer heating essentials smoke': 960,
#  'heating essentials smoke alarm': 487,
#  'essentials smoke alarm carbon': 358,
#  'smoke alarm carbon monoxide': 840,
#  'alarm carbon monoxide alarm': 16,
#  'carbon monoxide alarm first': 187,
#  'monoxide alarm first aid': 649,
#  'alarm first aid kit': 28,
#  'first aid kit fire': 408,
#  'aid kit fire extinguisher': 3,
#  'kit fire extinguisher lockbox': 548,
#  'hot water bed linens': 504,
#  'water bed linens microwave': 967,
#  'bed linens microwave coffee': 147,
#  'linens microwave coffee maker': 594,
#  'hot water kettle toaster': 513,
#  'area': 75,
#  'tv washer': 951,
#  'alarm bathtub': 13,
#  'bathtub hot': 129,
#  'silverware cooking': 820,
#  'outdoor dining': 680,
#  'dining area': 273,
#  'products drying': 768,
#  'monoxide alarm bathtub': 645,
#  'bathtub hot water': 130,
#  'and silverware cooking': 66,
#  'silverware cooking basics': 821,
#  'outdoor dining area': 681,
#  'cleaning products drying': 205,
#  'products drying rack': 769,
#  'conditioning wifi kitchen dryer': 241,
#  'carbon monoxide alarm bathtub': 185,
#  'bathtub hot water bed': 131,
#  'dishes and silverware cooking': 288,
#  'and silverware cooking basics': 67,
#  'cleaning products drying rack': 206,
#  'products drying rack for': 770,
#  'premises wifi': 752,
#  'kitchen dedicated': 558,
#  'linens extra': 589,
#  'alarm smoke': 37,
#  'alarm cooking': 20,
#  'basics dishes': 114,
#  'kettle microwave': 534,
#  'microwave oven': 633,
#  'on premises wifi': 669,
#  'premises wifi kitchen': 753,
#  'wifi kitchen dedicated': 992,
#  'kitchen dedicated workspace': 559,
#  'bed linens extra': 144,
#  'linens extra pillows': 590,
#  'monoxide alarm smoke': 651,
#  'alarm smoke alarm': 38,
#  'smoke alarm cooking': 843,
#  'alarm cooking basics': 21,
#  'cooking basics dishes': 250,
#  'basics dishes and': 115,
#  'water kettle microwave': 975,
#  'kettle microwave oven': 535,
#  'microwave oven refrigerator': 634,
#  'parking on premises wifi': 717,
#  'on premises wifi kitchen': 670,
#  'premises wifi kitchen dedicated': 754,
#  'wifi kitchen dedicated workspace': 993,
#  'kitchen dedicated workspace hair': 560,
#  'water bed linens extra': 966,
#  'bed linens extra pillows': 145,
#  'linens extra pillows and': 591,
#  'carbon monoxide alarm smoke': 189,
#  'monoxide alarm smoke alarm': 652,
#  'smoke alarm cooking basics': 844,
#  'alarm cooking basics dishes': 22,
#  'cooking basics dishes and': 251,
#  'basics dishes and silverware': 116,
#  'hot water kettle microwave': 510,
#  'water kettle microwave oven': 976,
#  'kettle microwave oven refrigerator': 536,
#  'breakfast': 175,
#  'wifi breakfast': 987,
#  'breakfast kitchen': 176,
#  'dryer shampoo': 319,
#  'essentials hot': 350,
#  'wifi breakfast kitchen': 988,
#  'dryer shampoo iron': 320,
#  'heating essentials hot': 482,
#  'essentials hot water': 351,
#  'dryer shampoo iron hangers': 321,
#  'washer heating essentials hot': 958,
#  'heating essentials hot water': 483,
#  'refrigerator stove': 786,
#  'oven refrigerator stove': 688,
#  'refrigerator stove toaster': 787,
#  'microwave oven refrigerator stove': 635,
#  'oven refrigerator stove toaster': 689,
#  'guards': 459,
#  'lock': 598,
#  'bedroom': 149,
#  'door': 302,
#  'nespresso': 657,
#  'paid': 704,
#  'off': 659,
#  'tv iron': 945,
#  'products hot': 771,
#  'kit lock': 549,
#  'lock on': 599,
#  'on bedroom': 664,
#  'bedroom door': 150,
#  'door smoke': 303,
#  'nespresso machine': 658,
#  'toaster wine': 930,
#  'paid parking': 705,
#  'parking off': 711,
#  'off premises': 660,
#  'premises long': 746,
#  'dryer tv iron': 323,
#  'tv iron hangers': 946,
#  'cleaning products hot': 207,
#  'products hot water': 772,
#  'aid kit lock': 4,
#  'kit lock on': 550,
#  'lock on bedroom': 600,
#  'on bedroom door': 665,
#  'bedroom door smoke': 151,
#  'door smoke alarm': 304,
#  'stove toaster wine': 896,
#  'toaster wine glasses': 931,
#  'paid parking off': 706,
#  'parking off premises': 712,
#  'premises long term': 747,
#  'hair dryer tv iron': 467,
#  'dryer tv iron hangers': 324,
#  'tv iron hangers washer': 947,
#  'cleaning products hot water': 208,
#  'first aid kit lock': 409,
#  'aid kit lock on': 5,
#  'kit lock on bedroom': 551,
#  'lock on bedroom door': 601,
#  'on bedroom door smoke': 666,
#  'bedroom door smoke alarm': 152,
#  'stove toaster wine glasses': 897,
#  'paid parking off premises': 707,
#  'premises long term stays': 748,
#  'fireplace dryer': 404,
#  'indoor fireplace dryer': 519,
#  'kitchen indoor fireplace dryer': 572,
#  'refrigerator stove toaster wine': 788,
#  'high': 488,
#  'chair': 190,
#  'pack': 700,
#  'play': 733,
#  'travel': 933,
#  'bathtub body': 124,
#  'high chair': 489,
#  'pack play': 701,
#  'play travel': 734,
#  'travel crib': 934,
#  'essentials bathtub body': 345,
#  'bathtub body soap': 125,
#  'pack play travel': 702,
#  'play travel crib': 735,
#  'heating essentials bathtub body': 479,
#  'essentials bathtub body soap': 346,
#  'bathtub body soap cleaning': 126,
#  'pack play travel crib': 703,
#  'host': 497,
#  'greets': 451,
#  'you': 1010,
#  'dryer hair': 315,
#  'host greets': 498,
#  'greets you': 452,
#  'kitchen dryer hair': 565,
#  'dryer hair dryer': 316,
#  'host greets you': 499,
#  'kitchen dryer hair dryer': 566,
#  'dryer hair dryer tv': 317,
#  'elevator': 335,
#  'iron washer': 526,
#  'microwave refrigerator': 636,
#  'balcony long': 102,
#  'or balcony long': 675,
#  'balcony long term': 103,
#  'patio or balcony long': 725,
#  'or balcony long term': 676,
#  'balcony long term stays': 104,
#  'single': 832,
#  'level': 579,
#  'home': 490,
#  'essentials free': 347,
#  'parking smoke': 718,
#  'alarm lockbox': 34,
#  'lockbox private': 606,
#  'entrance hot': 341,
#  'blankets microwave': 157,
#  'refrigerator dishwasher': 783,
#  'dishwasher dishes': 293,
#  'basics oven': 117,
#  'oven stove': 690,
#  'stove single': 892,
#  'single level': 833,
#  'level home': 580,
#  'home patio': 494,
#  'allowed hot': 46,
#  'kettle kitchenette': 533,
#  'table toaster': 909,
#  'clothing clothing': 210,
#  'storage wine': 877,
#  'heating essentials free': 480,
#  'essentials free street': 348,
#  'street parking smoke': 900,
#  'parking smoke alarm': 719,
#  'monoxide alarm lockbox': 650,
#  'lockbox private entrance': 607,
#  'private entrance hot': 759,
#  'entrance hot water': 342,
#  'and blankets microwave': 60,
#  'blankets microwave refrigerator': 160,
#  'microwave refrigerator dishwasher': 639,
#  'refrigerator dishwasher dishes': 784,
#  'dishwasher dishes and': 294,
#  'cooking basics oven': 252,
#  'basics oven stove': 118,
#  'oven stove single': 698,
#  'stove single level': 893,
#  'single level home': 834,
#  'level home patio': 583,
#  'home patio or': 495,
#  'stays allowed hot': 869,
#  'allowed hot water': 47,
#  'water kettle kitchenette': 974,
#  'dining table toaster': 281,
#  'table toaster freezer': 910,
#  'for clothing clothing': 413,
#  'clothing clothing storage': 211,
#  'clothing storage wine': 219,
#  'storage wine glasses': 878,
#  'premises wifi kitchen dryer': 755,
#  'washer heating essentials free': 957,
#  'heating essentials free street': 481,
#  'essentials free street parking': 349,
#  'free street parking smoke': 423,
#  'street parking smoke alarm': 901,
#  'parking smoke alarm carbon': 720,
#  'carbon monoxide alarm lockbox': 188,
#  'private entrance hot water': 760,
#  'pillows and blankets microwave': 731,
#  'and blankets microwave refrigerator': 62,
#  'microwave refrigerator dishwasher dishes': 640,
#  'refrigerator dishwasher dishes and': 785,
#  'dishwasher dishes and silverware': 295,
#  'silverware cooking basics oven': 822,
#  'cooking basics oven stove': 253,
#  'basics oven stove single': 122,
#  'oven stove single level': 699,
#  'stove single level home': 894,
#  'single level home patio': 836,
#  'level home patio or': 584,
#  'home patio or balcony': 496,
#  'term stays allowed hot': 919,
#  'stays allowed hot water': 870,
#  'allowed hot water kettle': 48,
#  'hot water kettle kitchenette': 509,
#  'dining table toaster freezer': 282,
#  'rack for clothing clothing': 776,
#  'for clothing clothing storage': 414,
#  'clothing clothing storage wine': 212,
#  'clothing storage wine glasses': 220,
#  'extinguisher private': 374,
#  'water body': 968,
#  'soap bed': 848,
#  'maker refrigerator': 624,
#  'grill patio': 456,
#  'balcony backyard': 99,
#  'backyard long': 88,
#  'kettle outdoor': 539,
#  'system dining': 903,
#  'toaster outdoor': 927,
#  'furniture freezer': 436,
#  'gel baking': 439,
#  'conditioner cleaning': 229,
#  'fire extinguisher private': 399,
#  'extinguisher private entrance': 375,
#  'hot water body': 505,
#  'water body soap': 969,
#  'body soap bed': 168,
#  'soap bed linens': 849,
#  'blankets microwave coffee': 158,
#  'coffee maker refrigerator': 225,
#  'maker refrigerator dishwasher': 627,
#  'bbq grill patio': 138,
#  'grill patio or': 457,
#  'or balcony backyard': 673,
#  'backyard long term': 89,
#  'water kettle outdoor': 979,
#  'kettle outdoor dining': 540,
#  'sound system dining': 857,
#  'system dining table': 904,
#  'table toaster outdoor': 912,
#  'toaster outdoor furniture': 928,
#  'outdoor furniture freezer': 685,
#  'shower gel baking': 811,
#  'gel baking sheet': 440,
#  'conditioner cleaning products': 230,
#  'wifi kitchen dryer hair': 996,
#  'fire extinguisher private entrance': 400,
#  'hot water body soap': 506,
#  'water body soap bed': 970,
#  'body soap bed linens': 169,
#  'soap bed linens extra': 850,
#  'and blankets microwave coffee': 61,
#  'blankets microwave coffee maker': 159,
#  'microwave coffee maker refrigerator': 632,
#  'coffee maker refrigerator dishwasher': 227,
#  'maker refrigerator dishwasher dishes': 628,
#  'bbq grill patio or': 139,
#  'grill patio or balcony': 458,
#  'patio or balcony backyard': 724,
#  'backyard long term stays': 90,
#  'hot water kettle outdoor': 512,
#  'water kettle outdoor dining': 980,
#  'kettle outdoor dining area': 541,
#  'sound system dining table': 858,
#  'dining table toaster outdoor': 283,
#  'table toaster outdoor furniture': 913,
#  'toaster outdoor furniture freezer': 929,
#  'shower gel baking sheet': 812,
#  'conditioner cleaning products drying': 231,
#  'ethernet': 359,
#  'connection': 242,
#  'kitchen hair': 567,
#  'blankets ethernet': 154,
#  'ethernet connection': 360,
#  'kettle mini': 537,
#  'allowed host': 43,
#  'kitchen hair dryer': 568,
#  'and blankets ethernet': 58,
#  'blankets ethernet connection': 155,
#  'water kettle mini': 977,
#  'kettle mini fridge': 538,
#  'paid parking on': 708,
#  'dropoff allowed host': 307,
#  'allowed host greets': 44,
#  'kitchen hair dryer tv': 569,
#  'pillows and blankets ethernet': 730,
#  'and blankets ethernet connection': 59,
#  'hot water kettle mini': 511,
#  'water kettle mini fridge': 978,
#  'paid parking on premises': 709,
#  'luggage dropoff allowed host': 616,
#  'dropoff allowed host greets': 308,
#  'allowed host greets you': 45,
#  'entrance bathtub': 340,
#  'area dining': 76,
#  'products clothing': 762,
#  'private entrance bathtub': 758,
#  'linens microwave refrigerator': 595,
#  'dining area dining': 274,
#  'area dining table': 77,
#  'cleaning products clothing': 201,
#  'products clothing storage': 763,
#  'bed linens microwave refrigerator': 148,
#  'linens microwave refrigerator dishwasher': 597,
#  'outdoor dining area dining': 682,
#  'dining area dining table': 275,
#  'area dining table toaster': 78,
#  'cleaning products clothing storage': 202,
#  'products clothing storage wine': 764,
#  'shampoo iron washer': 805,
#  'iron washer heating': 527,
#  'shampoo iron washer heating': 806,
#  'iron washer heating essentials': 528,
#  'dryer iron': 318,
#  'dishwasher microwave': 299,
#  'stove backyard': 880,
#  'wifi kitchen hair': 997,
#  'hair dryer iron': 463,
#  'silverware dishwasher microwave': 826,
#  'dishwasher microwave oven': 300,
#  'wifi kitchen hair dryer': 998,
#  'essentials hot water bed': 352,
#  'and silverware dishwasher microwave': 70,
#  'silverware dishwasher microwave oven': 827,
#  'dishwasher microwave oven refrigerator': 301,
#  'hangers heating': 470,
#  'crib pack': 257,
#  'extinguisher lock': 368,
#  'iron hangers heating': 522,
#  'hangers heating essentials': 471,
#  'crib pack play': 258,
#  'fire extinguisher lock': 395,
#  'extinguisher lock on': 369,
#  'shampoo iron hangers heating': 803,
#  'iron hangers heating essentials': 523,
#  'crib pack play travel': 259,
#  'fire extinguisher lock on': 396,
#  'extinguisher lock on bedroom': 370,
#  'washer smoke': 961,
#  'alarm lock': 31,
#  'washer smoke alarm': 962,
#  'alarm lock on': 32,
#  'alarm lock on bedroom': 33,
#  'essentials paid': 353,
#  'premises smoke': 749,
#  'refrigerator dishes': 780,
#  'stove long': 883,
#  'conditioner laundromat': 235,
#  'nearby cleaning': 654,
#  'heating essentials paid': 484,
#  'essentials paid parking': 354,
#  'off premises smoke': 661,
#  'premises smoke alarm': 750,
#  'maker refrigerator dishes': 625,
#  'refrigerator dishes and': 781,
#  'oven stove long': 692,
#  'stove long term': 884,
#  'conditioner laundromat nearby': 236,
#  'laundromat nearby cleaning': 577,
#  'nearby cleaning products': 655,
#  'washer heating essentials paid': 959,
#  'heating essentials paid parking': 485,
#  'essentials paid parking off': 355,
#  'parking off premises smoke': 713,
#  'off premises smoke alarm': 662,
#  'premises smoke alarm carbon': 751,
#  'coffee maker refrigerator dishes': 226,
#  'maker refrigerator dishes and': 626,
#  'refrigerator dishes and silverware': 782,
#  'basics oven stove long': 119,
#  'oven stove long term': 693,
#  'stove long term stays': 885,
#  'conditioner laundromat nearby cleaning': 237,
#  'laundromat nearby cleaning products': 578,
#  'nearby cleaning products drying': 656,
#  'alarm coffee': 17,
#  'smoke alarm coffee': 841,
#  'alarm coffee maker': 18,
#  'smoke alarm coffee maker': 842,
#  'workspace tv': 1009,
#  'stove bbq': 881,
#  'dedicated workspace tv': 271,
#  'stove bbq grill': 882,
#  'silverware freezer': 828,
#  'and silverware freezer': 71,
#  'silverware freezer hot': 829,
#  'dishes and silverware freezer': 290,
#  'and silverware freezer hot': 72,
#  'silverware freezer hot water': 830,
#  'kitchen dedicated workspace tv': 561,
#  'kitchen cable': 555,
#  'extinguisher smoke': 376,
#  'wifi kitchen cable': 990,
#  'kitchen cable tv': 556,
#  'fire extinguisher smoke': 401,
#  'extinguisher smoke alarm': 377,
#  'wifi kitchen cable tv': 991,
#  'fire extinguisher smoke alarm': 402,
#  'alarm coffee maker cooking': 19,
#  'maker cooking basics dishes': 623,
#  'area outdoor': 79,
#  'dining area outdoor': 276,
#  'area outdoor furniture': 80,
#  'outdoor dining area outdoor': 683,
#  'dining area outdoor furniture': 277,
#  'extinguisher lockbox private': 372,
#  'fire extinguisher lockbox private': 398,
#  'extinguisher lockbox private entrance': 373,
#  'alarm hot': 29,
#  'balcony luggage': 105,
#  'allowed long': 50,
#  'allowed cleaning': 40,
#  'you hot': 1011,
#  'alarm hot water': 30,
#  'or balcony luggage': 677,
#  'balcony luggage dropoff': 106,
#  'dropoff allowed long': 309,
#  'allowed long term': 51,
#  'stays allowed cleaning': 865,
#  'allowed cleaning available': 41,
#  'greets you hot': 453,
#  'you hot water': 1012,
#  'hangers heating essentials smoke': 472,
#  'patio or balcony luggage': 726,
#  'or balcony luggage dropoff': 678,
#  'balcony luggage dropoff allowed': 107,
#  'luggage dropoff allowed long': 617,
#  'dropoff allowed long term': 310,
#  'allowed long term stays': 52,
#  'term stays allowed cleaning': 917,
#  'stays allowed cleaning available': 866,
#  'allowed cleaning available during': 42,
#  'host greets you hot': 500,
#  'greets you hot water': 454,
#  'you hot water kettle': 1013,
#  'stove luggage': 886,
#  'freezer portable': 428,
#  'fans shower': 386,
#  'gel conditioner': 447,
#  'microwave refrigerator dishes': 637,
#  'oven stove luggage': 694,
#  'stove luggage dropoff': 887,
#  'freezer portable fans': 429,
#  'portable fans shower': 742,
#  'fans shower gel': 387,
#  'shower gel conditioner': 817,
#  'gel conditioner cleaning': 448,
#  'soap bed linens microwave': 851,
#  'linens microwave refrigerator dishes': 596,
#  'microwave refrigerator dishes and': 638,
#  'basics oven stove luggage': 120,
#  'oven stove luggage dropoff': 695,
#  'stove luggage dropoff allowed': 888,
#  'freezer portable fans shower': 430,
#  'portable fans shower gel': 743,
#  'fans shower gel conditioner': 389,
#  'shower gel conditioner cleaning': 818,
#  'gel conditioner cleaning products': 449,
#  'gym': 460,
#  'alarm private': 35,
#  'alarm private entrance': 36,
#  'bathtub hot water body': 132,
#  'fans shower gel baking': 388,
#  'shades hot': 795,
#  'kettle dining': 530,
#  'darkening shades hot': 265,
#  'shades hot water': 796,
#  'stays allowed host': 867,
#  'water kettle dining': 972,
#  'kettle dining table': 531,
#  'room darkening shades hot': 792,
#  'darkening shades hot water': 266,
#  'shades hot water bed': 797,
#  'term stays allowed host': 918,
#  'stays allowed host greets': 868,
#  'hot water kettle dining': 508,
#  'water kettle dining table': 973,
#  'crib room': 260,
#  'backyard luggage': 91,
#  'travel crib room': 937,
#  'crib room darkening': 261,
#  'balcony backyard luggage': 100,
#  'backyard luggage dropoff': 92,
#  'lockbox private entrance bathtub': 608,
#  'play travel crib room': 737,
#  'travel crib room darkening': 938,
#  'crib room darkening shades': 262,
#  'or balcony backyard luggage': 674,
#  'balcony backyard luggage dropoff': 101,
#  'backyard luggage dropoff allowed': 93,
#  'hair dryer shampoo': 464,
#  'hair dryer shampoo iron': 465,
#  'tv dryer hair': 943,
#  'kitchen cable tv dryer': 557,
#  'cable tv dryer hair': 181,
#  'tv dryer hair dryer': 944,
#  'silverware oven': 831,
#  'and silverware oven': 73,
#  'dishes and silverware oven': 291,
#  'extinguisher bathtub': 364,
#  'fire extinguisher bathtub': 392,
#  'home long': 491,
#  'level home long': 581,
#  'home long term': 492,
#  'single level home long': 835,
#  'level home long term': 582,
#  'home long term stays': 493,
#  'workspace hair dryer shampoo': 1007,
#  'gel cleaning': 445,
#  'shower gel cleaning': 815,
#  'gel cleaning products': 446,
#  'shower gel cleaning products': 816,
#  'elevator wifi': 336,
#  'elevator wifi kitchen': 337,
#  'smoke alarm first': 845,
#  'elevator wifi kitchen dryer': 338,
#  'smoke alarm first aid': 846,
#  'bathtub high': 127,
#  'connection microwave': 243,
#  'bathtub high chair': 128,
#  'ethernet connection microwave': 361,
#  'connection microwave coffee': 244,
#  'blankets ethernet connection microwave': 156,
#  'ethernet connection microwave coffee': 362,
#  'connection microwave coffee maker': 245,
#  'kettle dining table toaster': 532,
#  'lockbox bathtub': 603,
#  'crib hot': 255,
#  'crib hot water': 256,
#  'oven stove backyard': 691,
#  'freezer shower': 431,
#  'sheet conditioner': 808,
#  'freezer shower gel': 432,
#  'baking sheet conditioner': 97,
#  'gel baking sheet conditioner': 441,
#  'water microwave': 982,
#  'hot water microwave': 514,
#  'kitchen tv': 573,
#  'wifi kitchen tv': 1001,
#  'bathtub room': 133,
#  'premises freezer': 745,
#  'bathtub room darkening': 134,
#  'on premises freezer': 668,
#  'bathtub room darkening shades': 135,
#  'shades hot water body': 798,
#  'parking on premises freezer': 716,
#  'freezer shower gel conditioner': 433,
#  'stove patio': 889,
#  'oven stove patio': 696,
#  'stove patio or': 890,
#  'basics oven stove patio': 121,
#  'oven stove patio or': 697,
#  'stove patio or balcony': 891,
#  'toaster freezer shower': 925,
#  'table toaster freezer shower': 911,
#  'toaster freezer shower gel': 926,
#  ...}

# %%
len(bagofwords.vocabulary_)
# Out:
# 1014
