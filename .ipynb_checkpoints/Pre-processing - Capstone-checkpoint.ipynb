# %% [markdown]
# # Capstone Workbook 3: Pre-processing

# %%
# Import libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import data 
airbnb_ldn = pd.read_csv('airbnb_ldn_final.csv')

# %%
airbnb_ldn.drop(columns='Unnamed: 0', inplace=True)

# %%
airbnb_ldn.shape
# Out:
# (32674, 36)

# %%
airbnb_ldn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32674 entries, 0 to 32673
# Data columns (total 36 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Listing Title                                      32674 non-null  object
#  1   Property Type                                      32674 non-null  object
#  2   Listing Type                                       32674 non-null  object
#  3   City                                               32674 non-null  object
#  4   Zipcode                                            32674 non-null  object
#  5   Number of Reviews                                  32674 non-null  int64
#  6   Bedrooms                                           32674 non-null  object
#  7   Bathrooms                                          32674 non-null  int64
#  8   Max Guests                                         32674 non-null  int64
#  9   Airbnb Superhost                                   32674 non-null  object
#  10  Cancellation Policy                                18997 non-null  object
#  11  Cleaning Fee (Native)                              32674 non-null  float64
#  12  Extra People Fee(Native)                           32674 non-null  float64
#  13  Check-in Time                                      30917 non-null  object
#  14  Checkout Time                                      29533 non-null  object
#  15  Minimum Stay                                       32674 non-null  int64
#  16  Latitude                                           32674 non-null  float64
#  17  Longitude                                          32674 non-null  float64
#  18  Overall Rating                                     32674 non-null  float64
#  19  Airbnb Communication Rating                        32674 non-null  float64
#  20  Airbnb Accuracy Rating                             32674 non-null  float64
#  21  Airbnb Checkin Rating                              32674 non-null  float64
#  22  Airbnb Location Rating                             32674 non-null  float64
#  23  Airbnb Value Rating                                32674 non-null  float64
#  24  Amenities                                          32674 non-null  object
#  25  Airbnb Host ID                                     32674 non-null  int64
#  26  guest_controls                                     32674 non-null  object
#  27  Pets Allowed                                       32674 non-null  bool
#  28  Count Available Days LTM                           32674 non-null  int64
#  29  Count Blocked Days LTM                             32674 non-null  int64
#  30  Count Reservation Days LTM                         32674 non-null  int64
#  31  Occupancy Rate LTM                                 32674 non-null  int64
#  32  Number of Bookings LTM                             32674 non-null  int64
#  33  Number of Bookings LTM - Number of observed month  32674 non-null  int64
#  34  Average Daily Rate (Native)                        32674 non-null  float64
#  35  Annual Revenue LTM (Native)                        32674 non-null  float64
# dtypes: bool(1), float64(12), int64(11), object(12)
# memory usage: 8.8+ MB

# %%
# split into categorical and numerical columns
cat_cols = airbnb_ldn.select_dtypes(include='object')
num_cols = airbnb_ldn.select_dtypes(exclude='object')

# %%
# View categorical columns
cat_cols.head().T
# Out:
#                                                                      0  \
# Listing Title                        Cozy 2BR house with a garden view
# Property Type                                              Entire home
# Listing Type                                               entire_home
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             2
# Airbnb Superhost                                                     f
# Cancellation Policy                        strict_14_with_grace_period
# Check-in Time                                      12:00 PM - 12:00 AM
# Checkout Time                                                 10:00 AM
# Amenities            ['Free parking on premises', 'Air conditioning...
# guest_controls       {"allows_children": true, "allows_infants": tr...
#
#                                                                      1  \
# Listing Title          GuestReady - Amazing home with a private garden
# Property Type                                              Entire home
# Listing Type                                               entire_home
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             2
# Airbnb Superhost                                                     t
# Cancellation Policy                                                NaN
# Check-in Time                                       3:00 PM - 12:00 AM
# Checkout Time                                                 11:00 AM
# Amenities            ['Wifi', 'Kitchen', 'Dryer', 'Dedicated worksp...
# guest_controls       {"allows_children": true, "allows_infants": tr...
#
#                                                                      2  \
# Listing Title                            Cosy cottage on Richmond Park
# Property Type                                              Entire home
# Listing Type                                               entire_home
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             1
# Airbnb Superhost                                                     f
# Cancellation Policy                                                NaN
# Check-in Time                                            After 3:00 PM
# Checkout Time                                                 11:00 AM
# Amenities            ['Free parking on premises', 'Air conditioning...
# guest_controls       {"allows_children": false, "allows_infants": f...
#
#                                                                      3  \
# Listing Title        Entire Flat. Free parking, Garden , Richmond park
# Property Type                                       Entire rental unit
# Listing Type                                               entire_home
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             2
# Airbnb Superhost                                                     f
# Cancellation Policy                        strict_14_with_grace_period
# Check-in Time                                       3:00 PM - 11:00 PM
# Checkout Time                                                 11:00 AM
# Amenities            ['Free parking on premises', 'Wifi', 'Kitchen'...
# guest_controls       {"allows_children": true, "allows_infants": tr...
#
#                                                                      4
# Listing Title         Maisonette inbetween Richmond Park and Wimbledon
# Property Type                              Private room in rental unit
# Listing Type                                              private_room
# City                                                    Greater London
# Zipcode                                                         SW15 3
# Bedrooms                                                             1
# Airbnb Superhost                                                     f
# Cancellation Policy                        strict_14_with_grace_period
# Check-in Time                                      12:00 PM - 10:00 PM
# Checkout Time                                                 11:00 AM
# Amenities            ['Free parking on premises', 'Wifi', 'Breakfas...
# guest_controls       {"allows_children": false, "allows_infants": f...

# %% [markdown]
# ## Binary Columns
#
# Looking at the categorical columns, there are a couple that can immediately be identified as ones for some numerical transformation.
#
# To being with 'Airbnb Superhost' is a binary column and can thus be made numerical:

# %%
# confirm Airbnb superhost is binary:
airbnb_ldn['Airbnb Superhost']
# Out:
# 0        f
# 1        t
# 2        f
# 3        f
# 4        f
#         ..
# 32669    f
# 32670    f
# 32671    f
# 32672    f
# 32673    f
# Name: Airbnb Superhost, Length: 32674, dtype: object

# %% [markdown]
# The presence of two variables, f (false) and t (true) confirm the column is binary. It will now be made numerical:

# %%
# made the column binary in both dataframes
cat_cols['Airbnb Superhost'] = np.where(cat_cols['Airbnb Superhost'] == 't', 1, 0)
airbnb_ldn['Airbnb Superhost'] = np.where(airbnb_ldn['Airbnb Superhost'] == 't', 1, 0)

# %%
# check conversation has worked:
airbnb_ldn['Airbnb Superhost'].value_counts()
# Out:
# Airbnb Superhost
# 0    24696
# 1     7978
# Name: count, dtype: int64

# %% [markdown]
# Now looking at other columns with a small number of distinct values or potential for an increase in granularity. Initially identified ones:
#
# - Listing Type
# - Cancellation policy
# - Checkin time
# - Checkout time
# - Bedrooms
#
# ## Cancellation Policy

# %%
# check values within cancellation policy:
print(airbnb_ldn['Cancellation Policy'].value_counts())
print(f"Null values: {airbnb_ldn['Cancellation Policy'].isnull().sum()}")
# Out:
# Cancellation Policy
# strict_14_with_grace_period         7027
# moderate                            5671
# flexible                            4971
# better_strict_with_grace_period     1224
# super_strict_30                       60
# super_strict_60                       26
# firm_30_strict_with_grace_period      18
# Name: count, dtype: int64
# Null values: 13677

# %% [markdown]
# The cancellation policy can be split into several main categories - New grouping : original value;
# - No policy : Null values
# - Medium : moderate, flexible, luxury_moderate
# - Strict : strict_14_with_grace_period, better_strict_with_grace_period, firm_30_strict_with_grace_period
# - Super strict : super_strict_30, super_strict_60

# %%
# create mapping function to group cancellation policy data:
def map_cancellation_policy(i):
    if i in ['moderate', 'flexible', 'luxury_moderate']:
        return 'medium'
    elif i in ['strict_14_with_grace_period', 'better_strict_with_grace_period', 'firm_30_strict_with_grace_period']:
        return 'strict'
    elif i in ['super_strict_30', 'super_strict_60']:
        return 'super_strict'
    else:
        return 'no_policy'

# %%
# apply function to dataframe
airbnb_ldn['Cancellation Policy'] = airbnb_ldn['Cancellation Policy'].map(map_cancellation_policy)

# %%
# check appropriate transformation has been applied
airbnb_ldn['Cancellation Policy'].value_counts()
# Out:
# Cancellation Policy
# no_policy       13677
# medium          10642
# strict           8269
# super_strict       86
# Name: count, dtype: int64

# %% [markdown]
# The 'Cancellation Policy' column will now be one-hot encoded:

# %%
airbnb_ldn = pd.get_dummies(airbnb_ldn, columns = ['Cancellation Policy'])

# %%
airbnb_ldn.columns
# Out:
# Index(['Listing Title', 'Property Type', 'Listing Type', 'City', 'Zipcode',
#        'Number of Reviews', 'Bedrooms', 'Bathrooms', 'Max Guests',
#        'Airbnb Superhost', 'Cleaning Fee (Native)', 'Extra People Fee(Native)',
#        'Check-in Time', 'Checkout Time', 'Minimum Stay', 'Latitude',
#        'Longitude', 'Overall Rating', 'Airbnb Communication Rating',
#        'Airbnb Accuracy Rating', 'Airbnb Checkin Rating',
#        'Airbnb Location Rating', 'Airbnb Value Rating', 'Amenities',
#        'Airbnb Host ID', 'guest_controls', 'Pets Allowed',
#        'Count Available Days LTM', 'Count Blocked Days LTM',
#        'Count Reservation Days LTM', 'Occupancy Rate LTM',
#        'Number of Bookings LTM',
#        'Number of Bookings LTM - Number of observed month',
#        'Average Daily Rate (Native)', 'Annual Revenue LTM (Native)',
#        'Cancellation Policy_medium', 'Cancellation Policy_no_policy',
#        'Cancellation Policy_strict', 'Cancellation Policy_super_strict'],
#       dtype='object')

# %%
# change from 'bool' to 'int' datatype:
for col in ['Cancellation Policy_medium', 'Cancellation Policy_no_policy', 'Cancellation Policy_strict', 'Cancellation Policy_super_strict']:
    airbnb_ldn[col] = airbnb_ldn[col].astype(int)

# %% [markdown]
# ## Check-in Time
#
# The next column to transform will be the checkin time column, the number of distinct values will  be found:

# %%
# check number of distinct values in the dataframe
airbnb_ldn['Check-in Time'].value_counts()
# Out:
# Check-in Time
# After 3:00 PM         11044
# After 2:00 PM          2741
# Flexible               2261
# After 4:00 PM          1700
# 3:00 PM - 10:00 PM     1212
#                       ...
# After 11:00 PM            1
# After 6:00 AM             1
# 10:00 AM - 4:00 PM        1
# After 5:00 AM             1
# After %{time}             1
# Name: count, Length: 159, dtype: int64

# %%
# checking the null values for the 'Check-in Time' column:
airbnb_ldn['Check-in Time'].isnull().sum()
# Out:
# 1757

# %% [markdown]
# It can be seen that there are 160 distinct values in the 'Check-in Time' column (including nulls). This is quite a lot, hence a way or compressing these will be determined.
#
# To begin, it looks as though 'After 3: 00 PM' is the most common check-in time, there seem to be other columns that contain some element of 3pm. These will be investigated:

# %%
(airbnb_ldn[airbnb_ldn['Check-in Time'].str.contains('3', regex=True, na=False)])['Check-in Time'].value_counts()
# Out:
# Check-in Time
# After 3:00 PM                   11044
# 3:00 PM - 10:00 PM               1212
# 3:00 PM - 9:00 PM                 958
# 3:00 PM - 8:00 PM                 810
# 3:00 PM - 11:00 PM                713
# 3:00 PM - 12:00 AM                661
# 3:00 PM - 6:00 PM                 319
# 3:00 PM - 7:00 PM                 298
# 3:00 PM - 2:00 AM (next day)      298
# 3:00 PM - 5:00 PM                 136
# 3:00 PM - 1:00 AM (next day)      112
# 1:00 PM - 3:00 PM                  50
# 12:00 PM - 3:00 PM                 20
# 11:00 AM - 3:00 PM                 15
# 10:00 AM - 3:00 PM                  8
# 9:00 AM - 3:00 PM                   3
# 8:00 AM - 3:00 PM                   2
# After 3:00 AM                       2
# Name: count, dtype: int64

# %%
(airbnb_ldn[airbnb_ldn['Check-in Time'].str.startswith(('12', '1 ', '2', '3', '4', '5'), na=False)])['Check-in Time'].value_counts()
# Out:
# Check-in Time
# 3:00 PM - 10:00 PM               1212
# 3:00 PM - 9:00 PM                 958
# 3:00 PM - 8:00 PM                 810
# 3:00 PM - 11:00 PM                713
# 3:00 PM - 12:00 AM                661
# 2:00 PM - 10:00 PM                475
# 2:00 PM - 12:00 AM                325
# 3:00 PM - 6:00 PM                 319
# 4:00 PM - 10:00 PM                308
# 2:00 PM - 11:00 PM                307
# 3:00 PM - 7:00 PM                 298
# 3:00 PM - 2:00 AM (next day)      298
# 4:00 PM - 8:00 PM                 296
# 4:00 PM - 7:00 PM                 280
# 2:00 PM - 9:00 PM                 240
# 4:00 PM - 11:00 PM                209
# 2:00 PM - 8:00 PM                 182
# 4:00 PM - 12:00 AM                161
# 4:00 PM - 9:00 PM                 138
# 3:00 PM - 5:00 PM                 136
# 2:00 PM - 7:00 PM                 131
# 3:00 PM - 1:00 AM (next day)      112
# 2:00 PM - 6:00 PM                 102
# 2:00 PM - 2:00 AM (next day)       97
# 5:00 PM - 10:00 PM                 83
# 12:00 PM - 10:00 PM                81
# 2:00 PM - 4:00 PM                  81
# 4:00 PM - 2:00 AM (next day)       72
# 12:00 PM - 9:00 PM                 71
# 12:00 PM - 8:00 PM                 69
# 4:00 PM - 6:00 PM                  66
# 5:00 PM - 9:00 PM                  60
# 12:00 PM - 11:00 PM                58
# 12:00 PM - 12:00 AM                56
# 5:00 PM - 11:00 PM                 54
# 12:00 PM - 2:00 PM                 51
# 12:00 PM - 6:00 PM                 50
# 12:00 PM - 7:00 PM                 42
# 2:00 PM - 5:00 PM                  41
# 5:00 PM - 8:00 PM                  34
# 5:00 PM - 12:00 AM                 28
# 5:00 PM - 7:00 PM                  26
# 12:00 PM - 5:00 PM                 23
# 2:00 PM - 1:00 AM (next day)       22
# 12:00 PM - 3:00 PM                 20
# 12:00 PM - 4:00 PM                 18
# 5:00 PM - 2:00 AM (next day)       12
# 4:00 PM - 1:00 AM (next day)       11
# 12:00 PM - 2:00 AM (next day)       3
# 12:00 PM - 1:00 AM (next day)       2
# 5:00 PM - 1:00 AM (next day)        2
# Name: count, dtype: int64

# %% [markdown]
# **Complicated deadling with the checkin times, potentially return to at a later stage. Column will be ignored for now**

# %% [markdown]
# ## Checkout Time
#
# The next column to transform will be the check-out time column, the number of distinct values will  be found:

# %%
print(airbnb_ldn['Checkout Time'].value_counts())
print(f"Null values :  {airbnb_ldn['Checkout Time'].isnull().sum()}")
# Out:
# Checkout Time
# 11:00 AM    15268
# 10:00 AM     9025
# 12:00 PM     3964
# 1:00 PM       394
# 2:00 PM       252
# 9:00 AM       185
# 3:00 PM       135
# 12:00 AM       83
# 4:00 PM        60
# 5:00 PM        42
# 6:00 PM        36
# 8:00 AM        28
# 11:00 PM       14
# 2:00 AM        10
# 9:00 PM         9
# 1:00 AM         8
# 8:00 PM         6
# 7:00 PM         5
# 10:00 PM        4
# 3:00 AM         3
# 7:00 AM         2
# Name: count, dtype: int64
# Null values :  3141

# %% [markdown]
# Looking at the 'Checkout Time' column, there are 22 distinct time categories (including nulls), these can be divided into ... sub-groups (sub-group : values)
#
# - morning : 7:00 AM, 8:00 AM, 9:00 AM, 10:00 AM, 11:00 AM
# - afternoon : 12:00 PM, 1:00 PM, 2:00 PM, 3:00 PM, 4:00 PM, 5:00 PM
# - evening : 6:00 PM, 7:00 PM, 8:00 PM, 9:00 PM
# - late : 10:00 PM, 11:00 PM, 12:00 AM, 1:00 AM
# - very_early : 1:00 AM, 2:00 AM, 3:00 AM
# - none : NaN
#
# The column will be split into the described groups:

# %%
# create mapping function to 'Checkout Time' data:
def map_checkout_time(i):
    if i in ['7:00 AM', '8:00 AM', '9:00 AM', '10:00 AM', '11:00 AM']:
        return 'morning'
    elif i in ['12:00 PM', '1:00 PM', '2:00 PM', '3:00 PM', '4:00 PM', '5:00 PM']:
        return 'afternoon'
    elif i in ['6:00 PM', '7:00 PM', '8:00 PM', '9:00 PM']:
        return 'evening'
    elif i in ['10:00 PM', '11:00 PM', '12:00 PM', '1:00 AM']:
        return 'late'
    elif i in ['1:00 AM', '2:00 AM', '3:00 AM']:
        return 'very_early'
    else:
        return 'none'

# %%
# apply function to dataframe
airbnb_ldn['Checkout Time'] = airbnb_ldn['Checkout Time'].map(map_checkout_time)

# %%
# check the correct transformation has been applied:
airbnb_ldn['Checkout Time'].value_counts()
# Out:
# Checkout Time
# morning       24508
# afternoon      4847
# none           3224
# evening          56
# late             26
# very_early       13
# Name: count, dtype: int64

# %% [markdown]
# These different categories can now be one-hot encoded:

# %%
airbnb_ldn = pd.get_dummies(airbnb_ldn, columns = ['Checkout Time'])

# %%
airbnb_ldn.head().T
# Out:
#                                                                                                    0  \
# Listing Title                                                      Cozy 2BR house with a garden view
# Property Type                                                                            Entire home
# Listing Type                                                                             entire_home
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                  9
# Bedrooms                                                                                           2
# Bathrooms                                                                                          2
# Max Guests                                                                                         6
# Airbnb Superhost                                                                                   0
# Cleaning Fee (Native)                                                                          154.8
# Extra People Fee(Native)                                                                         0.0
# Check-in Time                                                                    12:00 PM - 12:00 AM
# Minimum Stay                                                                                       3
# Latitude                                                                                    51.43105
# Longitude                                                                                   -0.26074
# Overall Rating                                                                                   4.1
# Airbnb Communication Rating                                                                      9.0
# Airbnb Accuracy Rating                                                                           8.0
# Airbnb Checkin Rating                                                                            9.0
# Airbnb Location Rating                                                                           8.0
# Airbnb Value Rating                                                                              8.0
# Amenities                                          ['Free parking on premises', 'Air conditioning...
# Airbnb Host ID                                                                              91050428
# guest_controls                                     {"allows_children": true, "allows_infants": tr...
# Pets Allowed                                                                                   False
# Count Available Days LTM                                                                          10
# Count Blocked Days LTM                                                                           355
# Count Reservation Days LTM                                                                         5
# Occupancy Rate LTM                                                                                40
# Number of Bookings LTM                                                                             1
# Number of Bookings LTM - Number of observed month                                                  0
# Average Daily Rate (Native)                                                                    244.1
# Annual Revenue LTM (Native)                                                                   1619.5
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      0
# Cancellation Policy_strict                                                                         1
# Cancellation Policy_super_strict                                                                   0
# Checkout Time_afternoon                                                                        False
# Checkout Time_evening                                                                          False
# Checkout Time_late                                                                             False
# Checkout Time_morning                                                                           True
# Checkout Time_none                                                                             False
# Checkout Time_very_early                                                                       False
#
#                                                                                                    1  \
# Listing Title                                        GuestReady - Amazing home with a private garden
# Property Type                                                                            Entire home
# Listing Type                                                                             entire_home
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                 11
# Bedrooms                                                                                           2
# Bathrooms                                                                                          1
# Max Guests                                                                                         4
# Airbnb Superhost                                                                                   1
# Cleaning Fee (Native)                                                                            0.0
# Extra People Fee(Native)                                                                         0.0
# Check-in Time                                                                     3:00 PM - 12:00 AM
# Minimum Stay                                                                                       1
# Latitude                                                                                    51.43399
# Longitude                                                                                   -0.25656
# Overall Rating                                                                                   4.8
# Airbnb Communication Rating                                                                     10.0
# Airbnb Accuracy Rating                                                                           9.0
# Airbnb Checkin Rating                                                                           10.0
# Airbnb Location Rating                                                                           9.0
# Airbnb Value Rating                                                                             10.0
# Amenities                                          ['Wifi', 'Kitchen', 'Dryer', 'Dedicated worksp...
# Airbnb Host ID                                                                             476914024
# guest_controls                                     {"allows_children": true, "allows_infants": tr...
# Pets Allowed                                                                                   False
# Count Available Days LTM                                                                         163
# Count Blocked Days LTM                                                                           202
# Count Reservation Days LTM                                                                        91
# Occupancy Rate LTM                                                                                67
# Number of Bookings LTM                                                                            26
# Number of Bookings LTM - Number of observed month                                                 23
# Average Daily Rate (Native)                                                                    153.3
# Annual Revenue LTM (Native)                                                                  16737.7
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      1
# Cancellation Policy_strict                                                                         0
# Cancellation Policy_super_strict                                                                   0
# Checkout Time_afternoon                                                                        False
# Checkout Time_evening                                                                          False
# Checkout Time_late                                                                             False
# Checkout Time_morning                                                                           True
# Checkout Time_none                                                                             False
# Checkout Time_very_early                                                                       False
#
#                                                                                                    2  \
# Listing Title                                                          Cosy cottage on Richmond Park
# Property Type                                                                            Entire home
# Listing Type                                                                             entire_home
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                  1
# Bedrooms                                                                                           1
# Bathrooms                                                                                          2
# Max Guests                                                                                         3
# Airbnb Superhost                                                                                   0
# Cleaning Fee (Native)                                                                            0.0
# Extra People Fee(Native)                                                                         0.0
# Check-in Time                                                                          After 3:00 PM
# Minimum Stay                                                                                       7
# Latitude                                                                                      51.435
# Longitude                                                                                     -0.257
# Overall Rating                                                                                   5.0
# Airbnb Communication Rating                                                                     10.0
# Airbnb Accuracy Rating                                                                           8.0
# Airbnb Checkin Rating                                                                           10.0
# Airbnb Location Rating                                                                           8.0
# Airbnb Value Rating                                                                             10.0
# Amenities                                          ['Free parking on premises', 'Air conditioning...
# Airbnb Host ID                                                                              20985539
# guest_controls                                     {"allows_children": false, "allows_infants": f...
# Pets Allowed                                                                                   False
# Count Available Days LTM                                                                          74
# Count Blocked Days LTM                                                                           291
# Count Reservation Days LTM                                                                         1
# Occupancy Rate LTM                                                                                 2
# Number of Bookings LTM                                                                             0
# Number of Bookings LTM - Number of observed month                                                 -2
# Average Daily Rate (Native)                                                                    233.1
# Annual Revenue LTM (Native)                                                                    345.2
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      1
# Cancellation Policy_strict                                                                         0
# Cancellation Policy_super_strict                                                                   0
# Checkout Time_afternoon                                                                        False
# Checkout Time_evening                                                                          False
# Checkout Time_late                                                                             False
# Checkout Time_morning                                                                           True
# Checkout Time_none                                                                             False
# Checkout Time_very_early                                                                       False
#
#                                                                                                    3  \
# Listing Title                                      Entire Flat. Free parking, Garden , Richmond park
# Property Type                                                                     Entire rental unit
# Listing Type                                                                             entire_home
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                 20
# Bedrooms                                                                                           2
# Bathrooms                                                                                          1
# Max Guests                                                                                         4
# Airbnb Superhost                                                                                   0
# Cleaning Fee (Native)                                                                           34.8
# Extra People Fee(Native)                                                                         2.5
# Check-in Time                                                                     3:00 PM - 11:00 PM
# Minimum Stay                                                                                       5
# Latitude                                                                                    51.43531
# Longitude                                                                                   -0.25648
# Overall Rating                                                                                   4.8
# Airbnb Communication Rating                                                                     10.0
# Airbnb Accuracy Rating                                                                          10.0
# Airbnb Checkin Rating                                                                           10.0
# Airbnb Location Rating                                                                           9.0
# Airbnb Value Rating                                                                              9.0
# Amenities                                          ['Free parking on premises', 'Wifi', 'Kitchen'...
# Airbnb Host ID                                                                              65911292
# guest_controls                                     {"allows_children": true, "allows_infants": tr...
# Pets Allowed                                                                                   False
# Count Available Days LTM                                                                         138
# Count Blocked Days LTM                                                                           227
# Count Reservation Days LTM                                                                       108
# Occupancy Rate LTM                                                                                94
# Number of Bookings LTM                                                                            13
# Number of Bookings LTM - Number of observed month                                                  8
# Average Daily Rate (Native)                                                                     94.8
# Annual Revenue LTM (Native)                                                                  12853.3
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      0
# Cancellation Policy_strict                                                                         1
# Cancellation Policy_super_strict                                                                   0
# Checkout Time_afternoon                                                                        False
# Checkout Time_evening                                                                          False
# Checkout Time_late                                                                             False
# Checkout Time_morning                                                                           True
# Checkout Time_none                                                                             False
# Checkout Time_very_early                                                                       False
#
#                                                                                                    4
# Listing Title                                       Maisonette inbetween Richmond Park and Wimbledon
# Property Type                                                            Private room in rental unit
# Listing Type                                                                            private_room
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                  0
# Bedrooms                                                                                           1
# Bathrooms                                                                                          1
# Max Guests                                                                                         2
# Airbnb Superhost                                                                                   0
# Cleaning Fee (Native)                                                                            0.0
# Extra People Fee(Native)                                                                         0.0
# Check-in Time                                                                    12:00 PM - 10:00 PM
# Minimum Stay                                                                                       5
# Latitude                                                                                    51.43532
# Longitude                                                                                   -0.25413
# Overall Rating                                                                                   4.0
# Airbnb Communication Rating                                                                     10.0
# Airbnb Accuracy Rating                                                                          10.0
# Airbnb Checkin Rating                                                                           10.0
# Airbnb Location Rating                                                                           9.0
# Airbnb Value Rating                                                                              9.0
# Amenities                                          ['Free parking on premises', 'Wifi', 'Breakfas...
# Airbnb Host ID                                                                               4350839
# guest_controls                                     {"allows_children": false, "allows_infants": f...
# Pets Allowed                                                                                   False
# Count Available Days LTM                                                                           0
# Count Blocked Days LTM                                                                           365
# Count Reservation Days LTM                                                                         0
# Occupancy Rate LTM                                                                                55
# Number of Bookings LTM                                                                             0
# Number of Bookings LTM - Number of observed month                                                  6
# Average Daily Rate (Native)                                                                     44.2
# Annual Revenue LTM (Native)                                                                    267.8
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      0
# Cancellation Policy_strict                                                                         1
# Cancellation Policy_super_strict                                                                   0
# Checkout Time_afternoon                                                                        False
# Checkout Time_evening                                                                          False
# Checkout Time_late                                                                             False
# Checkout Time_morning                                                                           True
# Checkout Time_none                                                                             False
# Checkout Time_very_early                                                                       False

# %%
# change the datatype to integer
for col in ['Checkout Time_afternoon', 'Checkout Time_evening', 'Checkout Time_late', 'Checkout Time_morning', 'Checkout Time_none', 'Checkout Time_very_early']:
    airbnb_ldn[col] = airbnb_ldn[col].astype(int)

# %% [markdown]
# As shown, the 'Checkout Time' column has been split into the relevant categories.
#
# ## Bedrooms
#
# The 'Bedrooms' column will now be assessed:

# %%
print(airbnb_ldn['Bedrooms'].value_counts())
print(f"Null values: {airbnb_ldn['Bedrooms'].isnull().sum()}")
# Out:
# Bedrooms
# 1         19457
# 2          7541
# 3          2470
# Studio     1934
# 4           840
# 5           301
# 6            75
# 0            21
# 7            18
# 8             7
# 10            4
# 9             2
# 16            1
# 15            1
# 12            1
# 22            1
# Name: count, dtype: int64
# Null values: 0

# %% [markdown]
# There are 16 bedroom values. The 'Bedrooms' column is currently an 'object' column. This is due to the presence of 'Studio' within the columns data. For the purpose of modelling, it would be better if this column was a numerical datatype. Hence, the 'Studio' values, will be changed to the value '0.5' and the columns datatype will be converted to a 'float'.
#
# Begin with changing the 'Studio' values to '0.5':

# %%
airbnb_ldn['Bedrooms'] = airbnb_ldn['Bedrooms'].replace({'Studio' : '0.5'})

# %% [markdown]
# The column will now be converted to a 'float' datatype:

# %%
airbnb_ldn['Bedrooms'] = airbnb_ldn['Bedrooms'].astype(float)

# %% [markdown]
# ## Listing Type
#
# The 'Listing Type' column will now be evaluted:

# %%
airbnb_ldn['Listing Type'].unique()
# Out:
# array(['entire_home', 'private_room', 'shared_room', 'hotel_room'],
#       dtype=object)

# %% [markdown]
# Above are the four values present within the 'Listing Type' column. These can be one-hot encoded:

# %%
airbnb_ldn = pd.get_dummies(airbnb_ldn, columns = ['Listing Type'])

# %%
# convert to numerical binary
for col in ['Listing Type_entire_home', 'Listing Type_hotel_room', 'Listing Type_private_room', 'Listing Type_shared_room']:
    airbnb_ldn[col] = airbnb_ldn[col].astype('int')

# %%
airbnb_ldn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32674 entries, 0 to 32673
# Data columns (total 47 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Listing Title                                      32674 non-null  object
#  1   Property Type                                      32674 non-null  object
#  2   City                                               32674 non-null  object
#  3   Zipcode                                            32674 non-null  object
#  4   Number of Reviews                                  32674 non-null  int64
#  5   Bedrooms                                           32674 non-null  float64
#  6   Bathrooms                                          32674 non-null  int64
#  7   Max Guests                                         32674 non-null  int64
#  8   Airbnb Superhost                                   32674 non-null  int32
#  9   Cleaning Fee (Native)                              32674 non-null  float64
#  10  Extra People Fee(Native)                           32674 non-null  float64
#  11  Check-in Time                                      30917 non-null  object
#  12  Minimum Stay                                       32674 non-null  int64
#  13  Latitude                                           32674 non-null  float64
#  14  Longitude                                          32674 non-null  float64
#  15  Overall Rating                                     32674 non-null  float64
#  16  Airbnb Communication Rating                        32674 non-null  float64
#  17  Airbnb Accuracy Rating                             32674 non-null  float64
#  18  Airbnb Checkin Rating                              32674 non-null  float64
#  19  Airbnb Location Rating                             32674 non-null  float64
#  20  Airbnb Value Rating                                32674 non-null  float64
#  21  Amenities                                          32674 non-null  object
#  22  Airbnb Host ID                                     32674 non-null  int64
#  23  guest_controls                                     32674 non-null  object
#  24  Pets Allowed                                       32674 non-null  bool
#  25  Count Available Days LTM                           32674 non-null  int64
#  26  Count Blocked Days LTM                             32674 non-null  int64
#  27  Count Reservation Days LTM                         32674 non-null  int64
#  28  Occupancy Rate LTM                                 32674 non-null  int64
#  29  Number of Bookings LTM                             32674 non-null  int64
#  30  Number of Bookings LTM - Number of observed month  32674 non-null  int64
#  31  Average Daily Rate (Native)                        32674 non-null  float64
#  32  Annual Revenue LTM (Native)                        32674 non-null  float64
#  33  Cancellation Policy_medium                         32674 non-null  int32
#  34  Cancellation Policy_no_policy                      32674 non-null  int32
#  35  Cancellation Policy_strict                         32674 non-null  int32
#  36  Cancellation Policy_super_strict                   32674 non-null  int32
#  37  Checkout Time_afternoon                            32674 non-null  int32
#  38  Checkout Time_evening                              32674 non-null  int32
#  39  Checkout Time_late                                 32674 non-null  int32
#  40  Checkout Time_morning                              32674 non-null  int32
#  41  Checkout Time_none                                 32674 non-null  int32
#  42  Checkout Time_very_early                           32674 non-null  int32
#  43  Listing Type_entire_home                           32674 non-null  int32
#  44  Listing Type_hotel_room                            32674 non-null  int32
#  45  Listing Type_private_room                          32674 non-null  int32
#  46  Listing Type_shared_room                           32674 non-null  int32
# dtypes: bool(1), float64(13), int32(15), int64(11), object(7)
# memory usage: 9.6+ MB

# %% [markdown]
# ## Pets Allowed
#
# Looking at other binary columns. 'Pets Allowed' can be made into a binary column.

# %%
# convert 'pets allowed' to numerical
airbnb_ldn['Pets Allowed'] = airbnb_ldn['Pets Allowed'].astype('int')

# %% [markdown]
# Finish data preprocessing for now and move onto creating the first model.

# %%
airbnb_ldn.head().T
# Out:
#                                                                                                    0  \
# Listing Title                                                      Cozy 2BR house with a garden view
# Property Type                                                                            Entire home
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                  9
# Bedrooms                                                                                         2.0
# Bathrooms                                                                                          2
# Max Guests                                                                                         6
# Airbnb Superhost                                                                                   0
# Cleaning Fee (Native)                                                                          154.8
# Extra People Fee(Native)                                                                         0.0
# Check-in Time                                                                    12:00 PM - 12:00 AM
# Minimum Stay                                                                                       3
# Latitude                                                                                    51.43105
# Longitude                                                                                   -0.26074
# Overall Rating                                                                                   4.1
# Airbnb Communication Rating                                                                      9.0
# Airbnb Accuracy Rating                                                                           8.0
# Airbnb Checkin Rating                                                                            9.0
# Airbnb Location Rating                                                                           8.0
# Airbnb Value Rating                                                                              8.0
# Amenities                                          ['Free parking on premises', 'Air conditioning...
# Airbnb Host ID                                                                              91050428
# guest_controls                                     {"allows_children": true, "allows_infants": tr...
# Pets Allowed                                                                                       0
# Count Available Days LTM                                                                          10
# Count Blocked Days LTM                                                                           355
# Count Reservation Days LTM                                                                         5
# Occupancy Rate LTM                                                                                40
# Number of Bookings LTM                                                                             1
# Number of Bookings LTM - Number of observed month                                                  0
# Average Daily Rate (Native)                                                                    244.1
# Annual Revenue LTM (Native)                                                                   1619.5
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      0
# Cancellation Policy_strict                                                                         1
# Cancellation Policy_super_strict                                                                   0
# Checkout Time_afternoon                                                                            0
# Checkout Time_evening                                                                              0
# Checkout Time_late                                                                                 0
# Checkout Time_morning                                                                              1
# Checkout Time_none                                                                                 0
# Checkout Time_very_early                                                                           0
# Listing Type_entire_home                                                                           1
# Listing Type_hotel_room                                                                            0
# Listing Type_private_room                                                                          0
# Listing Type_shared_room                                                                           0
#
#                                                                                                    1  \
# Listing Title                                        GuestReady - Amazing home with a private garden
# Property Type                                                                            Entire home
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                 11
# Bedrooms                                                                                         2.0
# Bathrooms                                                                                          1
# Max Guests                                                                                         4
# Airbnb Superhost                                                                                   1
# Cleaning Fee (Native)                                                                            0.0
# Extra People Fee(Native)                                                                         0.0
# Check-in Time                                                                     3:00 PM - 12:00 AM
# Minimum Stay                                                                                       1
# Latitude                                                                                    51.43399
# Longitude                                                                                   -0.25656
# Overall Rating                                                                                   4.8
# Airbnb Communication Rating                                                                     10.0
# Airbnb Accuracy Rating                                                                           9.0
# Airbnb Checkin Rating                                                                           10.0
# Airbnb Location Rating                                                                           9.0
# Airbnb Value Rating                                                                             10.0
# Amenities                                          ['Wifi', 'Kitchen', 'Dryer', 'Dedicated worksp...
# Airbnb Host ID                                                                             476914024
# guest_controls                                     {"allows_children": true, "allows_infants": tr...
# Pets Allowed                                                                                       0
# Count Available Days LTM                                                                         163
# Count Blocked Days LTM                                                                           202
# Count Reservation Days LTM                                                                        91
# Occupancy Rate LTM                                                                                67
# Number of Bookings LTM                                                                            26
# Number of Bookings LTM - Number of observed month                                                 23
# Average Daily Rate (Native)                                                                    153.3
# Annual Revenue LTM (Native)                                                                  16737.7
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      1
# Cancellation Policy_strict                                                                         0
# Cancellation Policy_super_strict                                                                   0
# Checkout Time_afternoon                                                                            0
# Checkout Time_evening                                                                              0
# Checkout Time_late                                                                                 0
# Checkout Time_morning                                                                              1
# Checkout Time_none                                                                                 0
# Checkout Time_very_early                                                                           0
# Listing Type_entire_home                                                                           1
# Listing Type_hotel_room                                                                            0
# Listing Type_private_room                                                                          0
# Listing Type_shared_room                                                                           0
#
#                                                                                                    2  \
# Listing Title                                                          Cosy cottage on Richmond Park
# Property Type                                                                            Entire home
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                  1
# Bedrooms                                                                                         1.0
# Bathrooms                                                                                          2
# Max Guests                                                                                         3
# Airbnb Superhost                                                                                   0
# Cleaning Fee (Native)                                                                            0.0
# Extra People Fee(Native)                                                                         0.0
# Check-in Time                                                                          After 3:00 PM
# Minimum Stay                                                                                       7
# Latitude                                                                                      51.435
# Longitude                                                                                     -0.257
# Overall Rating                                                                                   5.0
# Airbnb Communication Rating                                                                     10.0
# Airbnb Accuracy Rating                                                                           8.0
# Airbnb Checkin Rating                                                                           10.0
# Airbnb Location Rating                                                                           8.0
# Airbnb Value Rating                                                                             10.0
# Amenities                                          ['Free parking on premises', 'Air conditioning...
# Airbnb Host ID                                                                              20985539
# guest_controls                                     {"allows_children": false, "allows_infants": f...
# Pets Allowed                                                                                       0
# Count Available Days LTM                                                                          74
# Count Blocked Days LTM                                                                           291
# Count Reservation Days LTM                                                                         1
# Occupancy Rate LTM                                                                                 2
# Number of Bookings LTM                                                                             0
# Number of Bookings LTM - Number of observed month                                                 -2
# Average Daily Rate (Native)                                                                    233.1
# Annual Revenue LTM (Native)                                                                    345.2
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      1
# Cancellation Policy_strict                                                                         0
# Cancellation Policy_super_strict                                                                   0
# Checkout Time_afternoon                                                                            0
# Checkout Time_evening                                                                              0
# Checkout Time_late                                                                                 0
# Checkout Time_morning                                                                              1
# Checkout Time_none                                                                                 0
# Checkout Time_very_early                                                                           0
# Listing Type_entire_home                                                                           1
# Listing Type_hotel_room                                                                            0
# Listing Type_private_room                                                                          0
# Listing Type_shared_room                                                                           0
#
#                                                                                                    3  \
# Listing Title                                      Entire Flat. Free parking, Garden , Richmond park
# Property Type                                                                     Entire rental unit
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                 20
# Bedrooms                                                                                         2.0
# Bathrooms                                                                                          1
# Max Guests                                                                                         4
# Airbnb Superhost                                                                                   0
# Cleaning Fee (Native)                                                                           34.8
# Extra People Fee(Native)                                                                         2.5
# Check-in Time                                                                     3:00 PM - 11:00 PM
# Minimum Stay                                                                                       5
# Latitude                                                                                    51.43531
# Longitude                                                                                   -0.25648
# Overall Rating                                                                                   4.8
# Airbnb Communication Rating                                                                     10.0
# Airbnb Accuracy Rating                                                                          10.0
# Airbnb Checkin Rating                                                                           10.0
# Airbnb Location Rating                                                                           9.0
# Airbnb Value Rating                                                                              9.0
# Amenities                                          ['Free parking on premises', 'Wifi', 'Kitchen'...
# Airbnb Host ID                                                                              65911292
# guest_controls                                     {"allows_children": true, "allows_infants": tr...
# Pets Allowed                                                                                       0
# Count Available Days LTM                                                                         138
# Count Blocked Days LTM                                                                           227
# Count Reservation Days LTM                                                                       108
# Occupancy Rate LTM                                                                                94
# Number of Bookings LTM                                                                            13
# Number of Bookings LTM - Number of observed month                                                  8
# Average Daily Rate (Native)                                                                     94.8
# Annual Revenue LTM (Native)                                                                  12853.3
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      0
# Cancellation Policy_strict                                                                         1
# Cancellation Policy_super_strict                                                                   0
# Checkout Time_afternoon                                                                            0
# Checkout Time_evening                                                                              0
# Checkout Time_late                                                                                 0
# Checkout Time_morning                                                                              1
# Checkout Time_none                                                                                 0
# Checkout Time_very_early                                                                           0
# Listing Type_entire_home                                                                           1
# Listing Type_hotel_room                                                                            0
# Listing Type_private_room                                                                          0
# Listing Type_shared_room                                                                           0
#
#                                                                                                    4
# Listing Title                                       Maisonette inbetween Richmond Park and Wimbledon
# Property Type                                                            Private room in rental unit
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                  0
# Bedrooms                                                                                         1.0
# Bathrooms                                                                                          1
# Max Guests                                                                                         2
# Airbnb Superhost                                                                                   0
# Cleaning Fee (Native)                                                                            0.0
# Extra People Fee(Native)                                                                         0.0
# Check-in Time                                                                    12:00 PM - 10:00 PM
# Minimum Stay                                                                                       5
# Latitude                                                                                    51.43532
# Longitude                                                                                   -0.25413
# Overall Rating                                                                                   4.0
# Airbnb Communication Rating                                                                     10.0
# Airbnb Accuracy Rating                                                                          10.0
# Airbnb Checkin Rating                                                                           10.0
# Airbnb Location Rating                                                                           9.0
# Airbnb Value Rating                                                                              9.0
# Amenities                                          ['Free parking on premises', 'Wifi', 'Breakfas...
# Airbnb Host ID                                                                               4350839
# guest_controls                                     {"allows_children": false, "allows_infants": f...
# Pets Allowed                                                                                       0
# Count Available Days LTM                                                                           0
# Count Blocked Days LTM                                                                           365
# Count Reservation Days LTM                                                                         0
# Occupancy Rate LTM                                                                                55
# Number of Bookings LTM                                                                             0
# Number of Bookings LTM - Number of observed month                                                  6
# Average Daily Rate (Native)                                                                     44.2
# Annual Revenue LTM (Native)                                                                    267.8
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      0
# Cancellation Policy_strict                                                                         1
# Cancellation Policy_super_strict                                                                   0
# Checkout Time_afternoon                                                                            0
# Checkout Time_evening                                                                              0
# Checkout Time_late                                                                                 0
# Checkout Time_morning                                                                              1
# Checkout Time_none                                                                                 0
# Checkout Time_very_early                                                                           0
# Listing Type_entire_home                                                                           0
# Listing Type_hotel_room                                                                            0
# Listing Type_private_room                                                                          1
# Listing Type_shared_room                                                                           0

# %% [markdown]
# ## Looking at the 'City' column:
#
# First, the number of distinct values within this column will be determined:

# %%
airbnb_ldn['City'].nunique()
# Out:
# 263

# %% [markdown]
# There are quite a few different values for city. Considering all the rows are specific to London postcodes, this is a surprisingly large amount of distinct values within the 'column'. This will be investigated further:

# %%
# determine what the distinct values within the 'city' column are:
airbnb_ldn['City'].unique()
# Out:
# array(['Greater London', 'London', 'Ealing', 'london', 'Chiswick',
#        'Wimbledon', 'England', 'Putney', 'West London', ' London',
#        'Hammersmith, London', 'Hammersmith', 'Central London', 'London ',
#        'Kensington', 'GB', 'Battersea ', 'West Sussex',
#        'South Kensington', 'London Kensington', 'Knightsbridge ',
#        'LONDON ', 'Pimlico', 'Central London ', 'Westminster',
#        'South Norwood', 'Croydon', 'London Borough of Lewisham',
#        'Brixton', 'Peckham, London', 'BETHWIN ROAD', 'Vauxhall',
#        'London Borough of Southwark', 'London South', 'Swan Mead', '*',
#        'Hanwell', 'Harrow', 'The Hyde', 'Edgware', 'Colindale ',
#        'Colindale', 'Mill hill Broadway ', 'North Kensington',
#        'London W8', 'Denbigh Road', 'Notting Hill', 'North Kensington ',
#        ' Notting Hill ,Greater London', 'Brent', 'Marylebone',
#        'City of Westminster', 'Paddington', 'Fitzrovia, London', 'LONDON',
#        'Maida Vale', 'Flask Walk ', 'Hampstead', 'Camden Town',
#        'United Kingdom', 'Londra', 'South Bank', 'Islington',
#        'London Borough of Islington', 'Golden Lane Estate', 'Shoreditch',
#        'Walthamstow', 'Greater London, Hackney', 'Poplar',
#        'London Borough of Tower Hamlets', 'Leven Road', 'Bow',
#        'Wharf Place', 'Hackney London', 'Hackney',
#        'London Borough of Hackney', 'East Village', 'East London',
#        'London Borough of Waltham Forest', 'Barnet', 'New Barnet',
#        'N144JN ', 'Enfield', 'Greenwich, London ', ' Woolwich London',
#        'Milne House', 'Shooters Hill', 'Woolwich', 'Walworth',
#        'Stratford London', 'Stratford, London', 'Stratford', 'LDN',
#        'Woodford', 'Kingston upon Thames', 'Richmond', 'Kew', 'Morden',
#        'wimbledon', 'Wimbledon, London', 'Wimbledon ', 'City of London',
#        'Merton', 'Wandsworth', 'Mitcham', 'Putney ',
#        'Southfields Wimbledon', 'East Putney ', 'Hammersmith London',
#        'London Borough of Hammersmith and Fulham',
#        'Hammersmith, Central London', 'Fulham', 'London, England',
#        'FULHAM, London', 'Fulham, London', 'Kensington Olympia',
#        'West Kensington', ' London ', 'Earls Court', 'Londre', 'Balham ',
#        'London Borough of Wandsworth', '倫敦', 'Battersea', 'London, UK',
#        'Clapham', 'Clapham London', ' Imperial Wharf', 'Chelsea',
#        'Chelsea, London', 'South Kensington Station',
#        ' Knightsbridge, London', 'Battersea,  London', 'London SW82AS',
#        'Nine Elms', 'London,', 'London City', 'London Westminster',
#        'Croydon/ Norwood Junction', 'Penge, London', 'Lancaster Avenue',
#        'Beckenham', 'Brixton London', 'Brixton ', 'Lambeth',
#        'East Dulwich, London', 'Camberwell', 'East Dulwich',
#        'Stockwell Gardens Estate', 'kennington', 'London, England, GB',
#        'Peckham', 'Peckham London ', 'Bermondsey', 'Borough',
#        '6 Rothsay Street', 'Bermondsey, London', 'Catford', 'Lewisham',
#        'South Bermondsey', 'Deptford, London', 'Ealing London',
#        'South Ealing', 'Ealing Broadway', 'Acton', 'East Acton ',
#        'Harlesden', 'London Borough of Brent', 'Kingsbury',
#        'kingsbury, london', 'Colindale, London', 'Mill Hill', 'Bushey',
#        "Shepherd's Bush", 'London -United Kingdom ',
#        'Road Shepherds Bush', 'Notting hill ', 'Bayswater',
#        'Royal Borough of Kensington and Chelsea', 'London  ',
#        'Maida Vale Greater London', 'London -Uk', 'Camden London',
#        'West Hampstead', 'Central London Narrowboat', 'Westminster ',
#        'london ', 'Mayfair', '.', 'Covent Garden', 'Great Britain',
#        'Hampstead village', 'London Borough of Camden',
#        'Hampstead Village, Greater London', 'Camden', 'Kentish Town',
#        'Tufnell Park', 'Hendon', 'Finchley', 'East Finchley',
#        'Highgate, London ', 'Muswell Hill, London',
#        'London Borough of Haringey', 'Crouch End', 'Muswell Hill',
#        'London Westminster Borough', 'Covent Garden London ',
#        'London Bridge', 'Holborn, London', 'Clerkenwell ', 'Clerkenwell',
#        'Kings Cross St Pancras', 'Clerkenwell, London ',
#        'Clerkenwell, London', 'central  London ', 'Finsbury',
#        'London Shoreditch', 'Londres', 'Drysdale Place',
#        'Greater London ', "King's Cross", 'Islington, London', 'Λονδίνο',
#        'Hoxton', 'Hackney, London', 'Mildmay Ward, Islington',
#        'Stoke Newington ', 'Shadwell', 'Limehouse ', 'Hannibal Road',
#        'Limehouse, London', 'Poplar ', 'Powis Road, Greater London',
#        'London Fields', 'Hackney, Greater London', 'Clapton',
#        'Hackney wick', 'Hackney ', 'Hackney Wick', 'Haringey',
#        "Duckett's Green", 'Tottenham', 'wood green',
#        'Leytonstone, London', 'Walthamstow Village', 'Chingford', 'Ridge',
#        'Chipping Barnet', 'Cockfosters', 'New Eltham', 'Greenwich',
#        'Greenwich, London', 'Greenwich ', 'Greenwich London',
#        'Greenwich, Greater London ', 'Londyn', 'East Ham', 'Newham',
#        'Umbriel Place', ' london', 'London Leytonstone ',
#        'South Woodford', 'South Woodford, '], dtype=object)

# %% [markdown]
# It looks as though a lot of the regional names of the different properties are listed within the 'city' column. The relative quantity of these will be determined:

# %%
airbnb_ldn['City'].value_counts().head(30)
# Out:
# City
# Greater London          25346
# London                   6553
# London                    106
# England                    54
#  London                    38
# Hammersmith                17
# Enfield                    16
# GB                         15
# Islington                  14
# New Barnet                 10
# Edgware                    10
# Putney                     10
# Bayswater                   9
# Barnet                      9
# Wimbledon                   9
# Central London              9
# Kensington                  8
# Brixton                     7
# Marylebone                  7
# Central London              7
# Hackney                     7
# United Kingdom              6
# Chiswick                    6
# Londra                      6
# Clapham                     6
# Limehouse, London           5
# Clerkenwell, London         5
# Ealing                      5
# Stratford                   5
# Hampstead                   5
# Name: count, dtype: int64

# %% [markdown]
# Looking at the 30 most common 'city' values, it can be seen that the vast majority of values contain 'Greater London', followed by just 'London'. It looks as though some property owners have labelled their properties borough/specific region within London, as the 'city'. As the information in this column is predominantly the same few general values ('Greater London' and 'London), and the other values giving more detail locational information. As the values within this column do not follow a continuous format, it wouldn't be helpful to use it in further analysis and therefore this column can be dropped.

# %%
airbnb_ldn.drop(columns='City', inplace=True)

# %% [markdown]
# Export the preprocessed data to CSV:

# %%
airbnb_ldn.to_csv('airbnb_ldn_pp.csv')
