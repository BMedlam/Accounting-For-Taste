# %% [markdown]
# # Capstone Workbook 4: Initial Modelling

# %%
# Import libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import data 
airbnb_ldn = pd.read_csv('airbnb_ldn_pp.csv')

# %%
# drop 'Unnamed: 0'
airbnb_ldn = airbnb_ldn.drop(columns = 'Unnamed: 0')

# %%
# View data:
airbnb_ldn.head().T
# Out:
#                                                                                                    0  \
# Listing Title                                                      Cozy 2BR house with a garden view
# Property Type                                                                            Entire home
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                  9
# Bedrooms                                                                                         2.0
# Bathrooms                                                                                          2
# Max Guests                                                                                         6
# Airbnb Superhost                                                                                   0
# Cleaning Fee (Native)                                                                          154.8
# Extra People Fee(Native)                                                                         0.0
# Check-in Time                                                                    12:00 PM - 12:00 AM
# Minimum Stay                                                                                       3
# Latitude                                                                                    51.43105
# Longitude                                                                                   -0.26074
# Overall Rating                                                                                   4.1
# Airbnb Communication Rating                                                                      9.0
# Airbnb Accuracy Rating                                                                           8.0
# Airbnb Cleanliness Rating                                                                        8.0
# Airbnb Checkin Rating                                                                            9.0
# Airbnb Location Rating                                                                           8.0
# Airbnb Value Rating                                                                              8.0
# Amenities                                          ['Free parking on premises', 'Air conditioning...
# Airbnb Host ID                                                                              91050428
# Host Listing Count                                                                               4.0
# guest_controls                                     {"allows_children": true, "allows_infants": tr...
# Pets Allowed                                                                                       0
# Count Available Days LTM                                                                          10
# Count Blocked Days LTM                                                                           355
# Count Reservation Days LTM                                                                         5
# Occupancy Rate LTM                                                                                40
# Number of Bookings LTM                                                                             1
# Number of Bookings LTM - Number of observed month                                                  0
# Average Daily Rate (Native)                                                                    244.1
# Annual Revenue LTM (Native)                                                                   1619.5
# Checkout Time_afternoon                                                                            0
# Checkout Time_evening                                                                              0
# Checkout Time_late                                                                                 0
# Checkout Time_morning                                                                              1
# Checkout Time_none                                                                                 0
# Checkout Time_very_early                                                                           0
# Listing Type_entire_home                                                                           1
# Listing Type_hotel_room                                                                            0
# Listing Type_private_room                                                                          0
# Listing Type_shared_room                                                                           0
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      0
# Cancellation Policy_strict                                                                         1
# Cancellation Policy_super_strict                                                                   0
#
#                                                                                                    1  \
# Listing Title                                        GuestReady - Amazing home with a private garden
# Property Type                                                                            Entire home
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                 11
# Bedrooms                                                                                         2.0
# Bathrooms                                                                                          1
# Max Guests                                                                                         4
# Airbnb Superhost                                                                                   1
# Cleaning Fee (Native)                                                                            0.0
# Extra People Fee(Native)                                                                         0.0
# Check-in Time                                                                     3:00 PM - 12:00 AM
# Minimum Stay                                                                                       1
# Latitude                                                                                    51.43399
# Longitude                                                                                   -0.25656
# Overall Rating                                                                                   4.8
# Airbnb Communication Rating                                                                     10.0
# Airbnb Accuracy Rating                                                                           9.0
# Airbnb Cleanliness Rating                                                                       10.0
# Airbnb Checkin Rating                                                                           10.0
# Airbnb Location Rating                                                                           9.0
# Airbnb Value Rating                                                                             10.0
# Amenities                                          ['Wifi', 'Kitchen', 'Dryer', 'Dedicated worksp...
# Airbnb Host ID                                                                             476914024
# Host Listing Count                                                                               NaN
# guest_controls                                     {"allows_children": true, "allows_infants": tr...
# Pets Allowed                                                                                       0
# Count Available Days LTM                                                                         163
# Count Blocked Days LTM                                                                           202
# Count Reservation Days LTM                                                                        91
# Occupancy Rate LTM                                                                                67
# Number of Bookings LTM                                                                            26
# Number of Bookings LTM - Number of observed month                                                 23
# Average Daily Rate (Native)                                                                    153.3
# Annual Revenue LTM (Native)                                                                  16737.7
# Checkout Time_afternoon                                                                            0
# Checkout Time_evening                                                                              0
# Checkout Time_late                                                                                 0
# Checkout Time_morning                                                                              1
# Checkout Time_none                                                                                 0
# Checkout Time_very_early                                                                           0
# Listing Type_entire_home                                                                           1
# Listing Type_hotel_room                                                                            0
# Listing Type_private_room                                                                          0
# Listing Type_shared_room                                                                           0
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      1
# Cancellation Policy_strict                                                                         0
# Cancellation Policy_super_strict                                                                   0
#
#                                                                                                    2  \
# Listing Title                                                          Cosy cottage on Richmond Park
# Property Type                                                                            Entire home
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                  1
# Bedrooms                                                                                         1.0
# Bathrooms                                                                                          2
# Max Guests                                                                                         3
# Airbnb Superhost                                                                                   0
# Cleaning Fee (Native)                                                                            0.0
# Extra People Fee(Native)                                                                         0.0
# Check-in Time                                                                          After 3:00 PM
# Minimum Stay                                                                                       7
# Latitude                                                                                      51.435
# Longitude                                                                                     -0.257
# Overall Rating                                                                                   5.0
# Airbnb Communication Rating                                                                     10.0
# Airbnb Accuracy Rating                                                                           8.0
# Airbnb Cleanliness Rating                                                                       10.0
# Airbnb Checkin Rating                                                                           10.0
# Airbnb Location Rating                                                                           8.0
# Airbnb Value Rating                                                                             10.0
# Amenities                                          ['Free parking on premises', 'Air conditioning...
# Airbnb Host ID                                                                              20985539
# Host Listing Count                                                                               NaN
# guest_controls                                     {"allows_children": false, "allows_infants": f...
# Pets Allowed                                                                                       0
# Count Available Days LTM                                                                          74
# Count Blocked Days LTM                                                                           291
# Count Reservation Days LTM                                                                         1
# Occupancy Rate LTM                                                                                 2
# Number of Bookings LTM                                                                             0
# Number of Bookings LTM - Number of observed month                                                 -2
# Average Daily Rate (Native)                                                                    233.1
# Annual Revenue LTM (Native)                                                                    345.2
# Checkout Time_afternoon                                                                            0
# Checkout Time_evening                                                                              0
# Checkout Time_late                                                                                 0
# Checkout Time_morning                                                                              1
# Checkout Time_none                                                                                 0
# Checkout Time_very_early                                                                           0
# Listing Type_entire_home                                                                           1
# Listing Type_hotel_room                                                                            0
# Listing Type_private_room                                                                          0
# Listing Type_shared_room                                                                           0
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      1
# Cancellation Policy_strict                                                                         0
# Cancellation Policy_super_strict                                                                   0
#
#                                                                                                    3  \
# Listing Title                                      Entire Flat. Free parking, Garden , Richmond park
# Property Type                                                                     Entire rental unit
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                 20
# Bedrooms                                                                                         2.0
# Bathrooms                                                                                          1
# Max Guests                                                                                         4
# Airbnb Superhost                                                                                   0
# Cleaning Fee (Native)                                                                           34.8
# Extra People Fee(Native)                                                                         2.5
# Check-in Time                                                                     3:00 PM - 11:00 PM
# Minimum Stay                                                                                       5
# Latitude                                                                                    51.43531
# Longitude                                                                                   -0.25648
# Overall Rating                                                                                   4.8
# Airbnb Communication Rating                                                                     10.0
# Airbnb Accuracy Rating                                                                          10.0
# Airbnb Cleanliness Rating                                                                        9.0
# Airbnb Checkin Rating                                                                           10.0
# Airbnb Location Rating                                                                           9.0
# Airbnb Value Rating                                                                              9.0
# Amenities                                          ['Free parking on premises', 'Wifi', 'Kitchen'...
# Airbnb Host ID                                                                              65911292
# Host Listing Count                                                                               4.0
# guest_controls                                     {"allows_children": true, "allows_infants": tr...
# Pets Allowed                                                                                       0
# Count Available Days LTM                                                                         138
# Count Blocked Days LTM                                                                           227
# Count Reservation Days LTM                                                                       108
# Occupancy Rate LTM                                                                                94
# Number of Bookings LTM                                                                            13
# Number of Bookings LTM - Number of observed month                                                  8
# Average Daily Rate (Native)                                                                     94.8
# Annual Revenue LTM (Native)                                                                  12853.3
# Checkout Time_afternoon                                                                            0
# Checkout Time_evening                                                                              0
# Checkout Time_late                                                                                 0
# Checkout Time_morning                                                                              1
# Checkout Time_none                                                                                 0
# Checkout Time_very_early                                                                           0
# Listing Type_entire_home                                                                           1
# Listing Type_hotel_room                                                                            0
# Listing Type_private_room                                                                          0
# Listing Type_shared_room                                                                           0
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      0
# Cancellation Policy_strict                                                                         1
# Cancellation Policy_super_strict                                                                   0
#
#                                                                                                    4
# Listing Title                                       Maisonette inbetween Richmond Park and Wimbledon
# Property Type                                                            Private room in rental unit
# City                                                                                  Greater London
# Zipcode                                                                                       SW15 3
# Number of Reviews                                                                                  0
# Bedrooms                                                                                         1.0
# Bathrooms                                                                                          1
# Max Guests                                                                                         2
# Airbnb Superhost                                                                                   0
# Cleaning Fee (Native)                                                                            0.0
# Extra People Fee(Native)                                                                         0.0
# Check-in Time                                                                    12:00 PM - 10:00 PM
# Minimum Stay                                                                                       5
# Latitude                                                                                    51.43532
# Longitude                                                                                   -0.25413
# Overall Rating                                                                                   4.0
# Airbnb Communication Rating                                                                     10.0
# Airbnb Accuracy Rating                                                                          10.0
# Airbnb Cleanliness Rating                                                                        6.0
# Airbnb Checkin Rating                                                                           10.0
# Airbnb Location Rating                                                                           9.0
# Airbnb Value Rating                                                                              9.0
# Amenities                                          ['Free parking on premises', 'Wifi', 'Breakfas...
# Airbnb Host ID                                                                               4350839
# Host Listing Count                                                                               0.0
# guest_controls                                     {"allows_children": false, "allows_infants": f...
# Pets Allowed                                                                                       0
# Count Available Days LTM                                                                           0
# Count Blocked Days LTM                                                                           365
# Count Reservation Days LTM                                                                         0
# Occupancy Rate LTM                                                                                55
# Number of Bookings LTM                                                                             0
# Number of Bookings LTM - Number of observed month                                                  6
# Average Daily Rate (Native)                                                                     44.2
# Annual Revenue LTM (Native)                                                                    267.8
# Checkout Time_afternoon                                                                            0
# Checkout Time_evening                                                                              0
# Checkout Time_late                                                                                 0
# Checkout Time_morning                                                                              1
# Checkout Time_none                                                                                 0
# Checkout Time_very_early                                                                           0
# Listing Type_entire_home                                                                           0
# Listing Type_hotel_room                                                                            0
# Listing Type_private_room                                                                          1
# Listing Type_shared_room                                                                           0
# Cancellation Policy_medium                                                                         0
# Cancellation Policy_no_policy                                                                      0
# Cancellation Policy_strict                                                                         1
# Cancellation Policy_super_strict                                                                   0

# %% [markdown]
# The data has now been cleaned, had some initial EDA completed and been preprocessed.
#
# Some initial models will now be built, starting with a regression model with a L1 penalty. This will help identify which columns are influencial in predicting the target column.
#
# First, the dataframe will be split into the independent and target variables, using just numerical variables for now:

# %%
X = airbnb_ldn.select_dtypes(exclude='object').drop(columns = 'Annual Revenue LTM (Native)')
y = airbnb_ldn['Annual Revenue LTM (Native)']

# %%
# drop all columns with null values:
X = X.drop(columns = ['Airbnb Communication Rating', 'Airbnb Accuracy Rating', 'Airbnb Cleanliness Rating', 'Airbnb Checkin Rating', 'Airbnb Location Rating', 'Airbnb Value Rating', 'Host Listing Count'])

# %%
X.shape
# Out:
# (32686, 34)

# %% [markdown]
# The dependent and target variables will now be split into into train and test sets:

# %%
# download required sklearn packages:
from sklearn.model_selection import train_test_split

# splitting data into train and test set:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=42)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (21899, 34)
# (21899,)

# %% [markdown]
# As random samples have been taken, the indexes for the dataframes will be reset:

# %%
# reset index for X training set:
X_train.reset_index(inplace=True)

# drop created 'index' column:
X_train.drop(columns='index', inplace=True)
# Out:
# C:\Users\blcm9\AppData\Local\Temp\ipykernel_12024\3935498988.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop(columns='index', inplace=True)

# %%
# reset index for X_test:
X_test.reset_index(inplace=True)

# drop created 'index column:
X_test.drop(columns='index', inplace=True)
# Out:
# C:\Users\blcm9\AppData\Local\Temp\ipykernel_12024\3863809310.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop(columns='index', inplace=True)

# %% [markdown]
# The index for the target column must also be reset:

# %%
# complete the same tranformation for the y_test data:
# convert the series to a dataframe:
y_train = y_train.to_frame()

# reset index
y_train.reset_index(inplace=True)

# drop 'index' column
y_train.drop(columns = 'index', inplace=True)

# return column to series
y_train = y_train.squeeze()

# %% [markdown]
# Complete the same tranformation for the y_test data:

# %%
# convert the series to a dataframe:
y_test = y_test.to_frame()

# reset index
y_test.reset_index(inplace=True)

# drop 'index' column
y_test.drop(columns = 'index', inplace=True)

# return column to series
y_test = y_test.squeeze()

# %% [markdown]
# Now the train and test datasets have been transferred, the first model can be made:

# %%
# import required libraries
from scipy import stats
import statsmodels.api as sm

# %%
# initiallly manually add the y-intercept:
X_train_withconstant = sm.add_constant(X_train)
X_test_withconstant = sm.add_constant(X_test)

# %%
# 1. instantiate model
myregression = sm.OLS(y_train, X_train_withconstant)

# fit model
myregression_results = myregression.fit()

# Looking at the summary
myregression_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     Annual Revenue LTM (Native)   R-squared:                       0.692
# Model:                                     OLS   Adj. R-squared:                  0.692
# Method:                          Least Squares   F-statistic:                     1641.
# Date:                         Sat, 23 Mar 2024   Prob (F-statistic):               0.00
# Time:                                 19:44:44   Log-Likelihood:            -2.3591e+05
# No. Observations:                        21899   AIC:                         4.719e+05
# Df Residuals:                            21868   BIC:                         4.721e+05
# Df Model:                                   30
# Covariance Type:                     nonrobust
# =====================================================================================================================
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# const                                                -0.0043      1.509     -0.003      0.998      -2.961       2.953
# Number of Reviews                                   -24.5546      1.728    -14.213      0.000     -27.941     -21.168
# Bedrooms                                           -295.4206    150.672     -1.961      0.050    -590.748      -0.093
# Bathrooms                                           143.6861    141.546      1.015      0.310    -133.755     421.127
# Max Guests                                          817.6309     69.164     11.822      0.000     682.064     953.198
# Airbnb Superhost                                    455.5591    194.801      2.339      0.019      73.734     837.384
# Cleaning Fee (Native)                                38.3364      2.470     15.524      0.000      33.496      43.177
# Extra People Fee(Native)                            -17.2931     10.183     -1.698      0.089     -37.253       2.666
# Minimum Stay                                         -4.2713      4.290     -0.996      0.319     -12.681       4.138
# Latitude                                           -112.8584   1950.125     -0.058      0.954   -3935.245    3709.528
# Longitude                                         -2308.8000   1055.194     -2.188      0.029   -4377.058    -240.542
# Overall Rating                                      -11.0819    163.426     -0.068      0.946    -331.409     309.245
# Airbnb Host ID                                     1.592e-07   5.28e-07      0.301      0.763   -8.77e-07     1.2e-06
# Pets Allowed                                        838.7513    234.811      3.572      0.000     378.505    1298.997
# Count Available Days LTM                             27.8094    275.321      0.101      0.920    -511.839     567.458
# Count Blocked Days LTM                              -29.3765    275.335     -0.107      0.915    -569.054     510.301
# Count Reservation Days LTM                           96.6085      3.917     24.664      0.000      88.931     104.286
# Occupancy Rate LTM                                   80.2669      4.605     17.431      0.000      71.241      89.293
# Number of Bookings LTM                              -90.5634     26.389     -3.432      0.001    -142.288     -38.839
# Number of Bookings LTM - Number of observed month    90.4407     25.845      3.499      0.000      39.783     141.098
# Average Daily Rate (Native)                          66.6219      0.713     93.473      0.000      65.225      68.019
# Checkout Time_afternoon                           -1016.9959    948.579     -1.072      0.284   -2876.280     842.289
# Checkout Time_evening                             -1629.3994   1776.702     -0.917      0.359   -5111.864    1853.065
# Checkout Time_late                                  -12.3237   2140.615     -0.006      0.995   -4208.084    4183.436
# Checkout Time_morning                              -793.2896    938.550     -0.845      0.398   -2632.916    1046.336
# Checkout Time_none                                 -900.8246    956.025     -0.942      0.346   -2774.704     973.055
# Checkout Time_very_early                           4352.8290   3966.683      1.097      0.273   -3422.157    1.21e+04
# Listing Type_entire_home                           2002.1432    404.056      4.955      0.000    1210.163    2794.123
# Listing Type_hotel_room                             -15.0436    796.550     -0.019      0.985   -1576.339    1546.251
# Listing Type_private_room                          -293.1078    408.145     -0.718      0.473   -1093.103     506.887
# Listing Type_shared_room                          -1693.9960    919.486     -1.842      0.065   -3496.254     108.262
# Cancellation Policy_medium                        -2392.3228    428.750     -5.580      0.000   -3232.705   -1551.941
# Cancellation Policy_no_policy                     -3107.1339    435.677     -7.132      0.000   -3961.092   -2253.176
# Cancellation Policy_strict                        -2647.7246    433.855     -6.103      0.000   -3498.112   -1797.337
# Cancellation Policy_super_strict                   8147.1770   1233.404      6.605      0.000    5729.615    1.06e+04
# ==============================================================================
# Omnibus:                    11578.050   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3055889.355
# Skew:                           1.366   Prob(JB):                         0.00
# Kurtosis:                      60.807   Cond. No.                     4.44e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.71e-17. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# The first model has produced fairly positive results. An R^2 value of 0.692 indicates that the approximately 70% of the variance within the Annual Revenue can be explained by the various numerical features.
#
# Let see how this model works with the test data:

# %% [markdown]
# A second more advanced linear model will now be produced. This second model will use an L1 penalty.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# scale the train and test variables:
X_train_scaled = StandardScaler().fit_transform(X_train_withconstant)
X_test_scaled = StandardScaler().fit_transform(X_test_withconstant)

# %%
# fit the model:
linreg = LinearRegression()
linreg.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
# Evaluate model
y_pred = linreg.predict(X_test_scaled)

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
r2 = r2_score(y_test, y_pred)

# %%
r2
# Out:
# 0.70855038540672
